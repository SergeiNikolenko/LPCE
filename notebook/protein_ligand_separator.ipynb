# %%
import sys
import warnings
import tempfile
import threading
import uuid
from dataclasses import dataclass
from pathlib import Path
from typing import List, Set, Tuple
import re
import numpy as np

from Bio.PDB.Polypeptide import standard_aa_names
from Bio.PDB import PDBParser, NeighborSearch, Select, PDBIO
from loguru import logger
import pymol
from pymol import cmd
from rdkit import Chem

from spyrmsd import graph, molecule, qcp

warnings.filterwarnings("ignore", category=UserWarning, module="MDAnalysis.core.universe")

logger.remove()
logger.add(sys.stdout, format="{message}", level="DEBUG")

BOND_LENGTHS = {
    ("C", "C"): 1.54,
    ("C", "N"): 1.6,
    ("C", "O"): 1.63,
    ("C", "S"): 1.80,
    ("P", "O"): 1.64,
    ("N", "O"): 1.55,
    ("N", "S"): 1.70,
    ("Fe", "S"): 2.33,
    ("Fe", "O"): 2.20,
    ("Fe", "N"): 2.15,
    ("Zn", "S"): 2.35,
    ("Zn", "N"): 2.16,
    ("Zn", "O"): 2.22,
    ("Cu", "S"): 2.26,
    ("Cu", "N"): 1.98,
    ("Cu", "O"): 1.95,
    ("Ni", "S"): 2.28,
    ("Ni", "N"): 2.08,
    ("Ni", "O"): 2.10,
    ("Mn", "O"): 2.18,
    ("Mn", "N"): 2.10,
    ("Co", "S"): 2.22,
    ("Co", "N"): 2.05,
    ("Co", "O"): 2.10,
    ("Mg", "O"): 2.08,
    ("Ca", "O"): 2.45,
    ("Mo", "S"): 2.42,
    ("Mo", "O"): 2.00,
    ("Na", "O"): 2.35,
    ("K", "O"): 2.75,
}

METALS = {"Fe", "Zn", "Cu", "Ni", "Mn", "Co", "Mg", "Ca", "Mo", "Na", "K"}

def _get_bond_threshold(el1, el2, default_bond_distance):
    pair = (el1, el2)
    if pair in BOND_LENGTHS:
        return BOND_LENGTHS[pair]
    rev = (el2, el1)
    if rev in BOND_LENGTHS:
        return BOND_LENGTHS[rev]
    return default_bond_distance

def _elem(atom) -> str:
    e = getattr(atom, "element", "").strip()
    if e:
        return e.capitalize()
    name = atom.get_name().strip()
    m = re.match(r"([A-Za-z]{1,2})", name)
    if not m:
        return name[0].upper()
    s = m.group(1).upper()
    return s.capitalize()

class _PymolSession:
    _lock = threading.Lock()
    _started = False

    @classmethod
    def ensure(cls) -> None:
        with cls._lock:
            if not cls._started:
                pymol.finish_launching(["pymol", "-qc"])
                cls._started = True

    @classmethod
    def locked(cls):
        cls.ensure()
        return cls._lock


def _ligands_connected(r1, r2, default_bond_distance):
    for a1 in r1.get_atoms():
        for a2 in r2.get_atoms():
            el1 = _elem(a1)
            el2 = _elem(a2)
            thr = _get_bond_threshold(el1, el2, default_bond_distance)
            dist = np.linalg.norm(a1.coord - a2.coord)
            logger.debug(f"_ligands_connected: Checking {r1.get_resname()}-{r2.get_resname()} : "
                         f"{a1.get_name()}-{a2.get_name()}, dist={dist:.3f}, thr={thr}")
            if dist <= thr:
                logger.debug(f"_ligands_connected: FOUND BOND between {r1.get_resname()} and {r2.get_resname()}")
                return True
    return False

def _rmsd_on_ca(pdb1: str, pdb2: str) -> float:
    with _PymolSession.locked():
        o1, o2 = f"o{uuid.uuid4().hex}", f"o{uuid.uuid4().hex}"
        cmd.delete("all")
        cmd.load(pdb1, o1)
        cmd.load(pdb2, o2)
        try:
            return float(cmd.align(f"{o1} and name CA", f"{o2} and name CA")[0])
        finally:
            cmd.delete("all")


def _rmsd_on_ligand(pdb1: str, pdb2: str) -> float:
    with _PymolSession.locked():
        o1, o2 = f"o{uuid.uuid4().hex}", f"o{uuid.uuid4().hex}"
        cmd.delete("all")
        cmd.load(pdb1, o1)
        cmd.load(pdb2, o2)

        cmd.align(f"{o1} and name CA", f"{o2} and name CA", cycles=0)

        def _dump(obj, fn):
            tmp_obj = f"{obj}_x"
            cmd.create(tmp_obj, obj, 1, 1)
            cmd.save(fn, f"{tmp_obj} and hetatm and not resn HOH", state=1)
            cmd.delete(tmp_obj)

        t1 = tempfile.NamedTemporaryFile(suffix=".pdb", delete=False)
        t2 = tempfile.NamedTemporaryFile(suffix=".pdb", delete=False)
        _dump(o1, t1.name)
        _dump(o2, t2.name)

        m1 = Chem.MolFromPDBFile(t1.name, removeHs=False)
        m2 = Chem.MolFromPDBFile(t2.name, removeHs=False)
        t1.close()
        t2.close()
        if not m1 or not m2:
            logger.debug("    ligand RMSD -> RDKit build failed (m1 or m2 is None)")
            cmd.delete("all")
            return float("inf")

        c1 = np.array([a.coord for a in cmd.get_model(o1 + " and hetatm and not resn HOH").atom])
        c2 = np.array([a.coord for a in cmd.get_model(o2 + " and hetatm and not resn HOH").atom])

        try:
            mol1 = molecule.Molecule.from_rdkit(m1)
            mol2 = molecule.Molecule.from_rdkit(m2)
            G1 = graph.graph_from_adjacency_matrix(mol1.adjacency_matrix, mol1.atomicnums)
            G2 = graph.graph_from_adjacency_matrix(mol2.adjacency_matrix, mol2.atomicnums)


            for idx1, idx2 in graph.match_graphs(G1, G2):
                r = np.sqrt(np.mean((c1[idx1] - c2[idx2]) ** 2))
                logger.debug("    ligand RMSD -> graph mode matched. RMSD=%.3f" % r)
                cmd.delete("all")
                return float(r)
        except Exception as e:
            logger.debug(f"    ligand RMSD -> graph error: {e}")

        logger.debug("    ligand RMSD -> return inf (no match)")
        cmd.delete("all")
        return float("inf")


class _LigandPocketSelect(Select):
    def __init__(self, ligands, chains):
        self._ligand_ids = {(r.get_parent().id, r.id) for r in ligands}
        self._chains = chains

    def accept_chain(self, chain):
        return chain.id in self._chains or any(chain.id == cid for cid, _ in self._ligand_ids)

    def accept_residue(self, residue):
        cid = residue.get_parent().id
        return (cid, residue.id) in self._ligand_ids or residue.id[0] == " "


@dataclass
class Pocket:
    ligands: List
    chains: Set[str]
    bond_type: str


class LigandPocketExtractor:

    def __init__(self, interact_d=4.5, ligand_cluster_d=1.5, default_bond_d=1.5, short_peptide=10):
        self.interact_d = interact_d
        self.default_bond_d = default_bond_d
        self.short_peptide = short_peptide
        self.ligand_cluster_d = max(ligand_cluster_d, default_bond_d)
        self._search_radius = max(self.ligand_cluster_d, max(BOND_LENGTHS.values(), default=0.0))

    @staticmethod
    def _chains_near(lig_atoms, prot_atoms, d):
        ns = NeighborSearch(prot_atoms)
        return {a.get_parent().get_parent().id
                for la in lig_atoms
                for a in ns.search(la.coord, d, level="A")}

    @staticmethod
    def _save_temp(structure, selector):
        io = PDBIO()
        tmp = tempfile.NamedTemporaryFile(suffix=".pdb", delete=False)
        io.set_structure(structure)
        io.save(tmp.name, select=selector)
        tmp.close()
        return tmp.name

    def _check_bond_type(self, la, pa):
        el_l = _elem(la)
        el_p = _elem(pa)
        thr = _get_bond_threshold(el_l, el_p, self.default_bond_d)
        dist = np.linalg.norm(la.coord - pa.coord)
        if dist <= thr:
            if el_l in METALS or el_p in METALS:
                return "coord"
            return "cov"
        return None

    def _get_pocket_bond_type(self, lig_atoms, prot_atoms):

        hoa_atoms = [a for a in lig_atoms if a.get_parent().get_resname() == "HOA"]
        
        if hoa_atoms:
            from Bio.PDB import Selection
            all_atoms = list(Selection.unfold_entities(hoa_atoms[0].get_parent().get_parent().get_parent(), 'A'))
            all_ns = NeighborSearch(all_atoms)
            

            for la in hoa_atoms:
                logger.debug(f"DEBUG: Atoms near {la.get_parent().get_resname()}:{la.get_name()} within 5.0 Å:")
                for neighbor in all_ns.search(la.coord, 3.0, level="A"):
                    res = neighbor.get_parent()
                    logger.debug(f"  {res.get_parent().id}/{res.get_resname()}{res.id[1]}/{neighbor.get_name()} = {np.linalg.norm(la.coord - neighbor.coord):.3f} Å")
        

        p_ns = NeighborSearch(prot_atoms)
        all_ns = NeighborSearch(prot_atoms + lig_atoms)


        for la in lig_atoms:
            for pa in all_ns.search(la.coord, 3.0, level="A"):
                if pa is la:
                    continue
                if _elem(la) in METALS or _elem(pa) in METALS:
                    bt = self._check_bond_type(la, pa)
                    if bt == "coord":
                        return "coord"


        for la in lig_atoms:
            for pa in p_ns.search(la.coord, 3.0, level="A"): 
                bt = self._check_bond_type(la, pa)
                if bt == "cov":
                    return "cov"

        return ""

    def extract(self, structure):

        if len(structure) > 1:
            logger.debug("extract: multiple models, using first model.")
            structure = structure[0]

        chain_res = {}
        for r in structure.get_residues():
            chain_res.setdefault(r.get_parent().id, []).append(r)

        protein_chains = {cid for cid, res in chain_res.items()
                          if sum(1 for r in res if r.id[0] == " ") > self.short_peptide}

        prot_atoms = [a for a in structure.get_atoms()
                      if a.get_parent().id[0] == " "
                      and a.get_parent().get_parent().id in protein_chains]
        
        for cid, reslist in chain_res.items():
            logger.debug(f"Chain {cid} has {len(reslist)} residues. "
                         f"Num_std={sum(1 for r in reslist if r.id[0]==' ')}")


        candidates = [r for r in structure.get_residues()
                      if (r.id[0] != " " and r.get_resname() != "HOH")
                      or len(chain_res[r.get_parent().id]) <= self.short_peptide]

        logger.debug(f"Candidate residues: {len(candidates)}")

        index = {r: i for i, r in enumerate(candidates)}
        parent = list(range(len(candidates)))

        def find(i):
            while parent[i] != i:
                parent[i] = parent[parent[i]]
                i = parent[i]
            return i

        def union(i, j):
            pi, pj = find(i), find(j)
            if pi != pj:
                parent[pj] = pi

        ns = NeighborSearch([a for r in candidates for a in r.get_atoms()])
        for r in candidates:
            i = index[r]
            for a in r.get_atoms():
                for n in ns.search(a.coord, self._search_radius, level="A"):
                    r2 = n.get_parent()
                    if r2 is r or r2 not in index:
                        continue
                    dist = np.linalg.norm(a.coord - n.coord)
                    thr = _get_bond_threshold(_elem(a), _elem(n), self.ligand_cluster_d)
                    if dist <= thr:
                        union(i, index[r2])

        components = {}
        for r in candidates:
            components.setdefault(find(index[r]), []).append(r)

        pockets = []
        for residues in components.values():
            lig_atoms = [a for rr in residues for a in rr.get_atoms()]
            chains = self._chains_near(lig_atoms, prot_atoms, self.interact_d)
            if not chains:
                continue
            btype = self._get_pocket_bond_type(lig_atoms, prot_atoms)
            logger.debug(f"New pocket with residues {[r.get_resname() for r in residues]} -> bond={btype}, chains={chains}")
            pockets.append(Pocket(residues, chains, btype))

        logger.debug(f"Pockets found: {len(pockets)}")
        return pockets


class PocketWriter:

    def __init__(self,
                 rmsd_thr=2.0,
                 lig_rmsd_thr=0.5,
                 ligand_cluster_distance=3.0,
                 default_bond_distance=1.5):
        self.rmsd_thr = rmsd_thr
        self.lig_rmsd_thr = lig_rmsd_thr
        self.ligand_cluster_distance = max(ligand_cluster_distance,
                                           default_bond_distance,
                                           max(BOND_LENGTHS.values()))
        
        self.default_bond_distance = default_bond_distance
        self._saved = []

    def _is_duplicate(self, new_tmp: str, lig_resnames: List[str], new_chains: Set[str]) -> bool:
        new_names = set(lig_resnames)
        for s in self._saved:
            same_chains = s["chains"] == new_chains
            if not same_chains:
                rmsd_p = _rmsd_on_ca(s["tmp"], new_tmp)
                logger.debug(f"    Protein RMSD = {rmsd_p:.3f} Å (thr {self.rmsd_thr})")
                if rmsd_p >= self.rmsd_thr:
                    continue
            if new_names != set(s["ligand_res"]):
                continue
            rmsd_l = _rmsd_on_ligand(s["tmp"], new_tmp)
            logger.debug(f"    Ligand RMSD  = {rmsd_l:.3f} Å (thr {self.lig_rmsd_thr})")
            if rmsd_l < self.lig_rmsd_thr:
                logger.debug("    -> duplicate detected, skip")
                return True
        return False

    def save(self, structure, pocket: Pocket, out_dir: Path, extra_lines: List[str], pdb_basename: str) -> None:
        lig_all = {r.get_resname() for r in pocket.ligands if r.get_resname() != "HOH"}
        if not lig_all:
            return
        logger.debug(f"save: pocket has ligands {lig_all}, bond_type={pocket.bond_type}")
        het = sorted([r for r in lig_all if r not in standard_aa_names])
        pep = sorted([r for r in lig_all if r in standard_aa_names])
        lig_resnames = het + pep

        if len(lig_resnames) == 1:
            lig_code = lig_resnames[0]
            logger.debug(f"save: single ligand {lig_code}")
        else:
            logger.debug(f"save: multiple ligands {lig_resnames}, checking connectivity...")
            real_ligands = [r for r in pocket.ligands if r.get_resname() in lig_resnames]
            coords = [np.array([a.coord for a in r.get_atoms()]) for r in real_ligands]
            min_d = min(
                np.min(np.linalg.norm(c1[:, None, :] - c2[None, :, :], axis=-1))
                for i, c1 in enumerate(coords)
                for c2 in coords[i + 1:]
            )
            logger.debug(f"save: minimal distance among ligands in pocket is {min_d:.3f}")

            connected_pairs = []
            for i in range(len(real_ligands)):
                for j in range(i + 1, len(real_ligands)):
                    if _ligands_connected(real_ligands[i], real_ligands[j], self.default_bond_distance):
                        logger.debug(f"save: LIGANDS {real_ligands[i].get_resname()} and {real_ligands[j].get_resname()} are connected -> union them")
                        connected_pairs.append((i, j))

            parent = list(range(len(real_ligands)))
            def find(x):
                while parent[x] != x:
                    parent[x] = parent[parent[x]]
                    x = parent[x]
                return x
            def union(x, y):
                rx, ry = find(x), find(y)
                if rx != ry:
                    parent[ry] = rx

            for (i, j) in connected_pairs:
                union(i, j)

            comps = {}
            for i, lig in enumerate(real_ligands):
                leader = find(i)
                comps.setdefault(leader, []).append(lig.get_resname())

            group_names = []
            for v in comps.values():
                name = "".join(sorted(v))
                group_names.append(name)
            if len(group_names) == 1:
                lig_code = group_names[0]
            else:
                lig_code = "_".join(group_names)
            logger.debug(f"save: final lig_code={lig_code}")

        chains_code = "_".join(sorted(pocket.chains))
        parts = [pdb_basename, lig_code, "chains", chains_code]
        if pocket.bond_type == "coord":
            parts.append("coord")
        elif pocket.bond_type == "cov":
            parts.append("cov")
        root = "_".join(parts)
        out_path = out_dir / f"{root}.pdb"
        v = 2
        while out_path.exists():
            out_path = out_dir / f"{root}_v{v}.pdb"
            v += 1

        selector = _LigandPocketSelect(pocket.ligands, pocket.chains)
        tmp = LigandPocketExtractor._save_temp(structure, selector)
        logger.debug(f"Duplicate check for: {out_path.name}")
        if self._is_duplicate(tmp, lig_resnames, pocket.chains):
            Path(tmp).unlink(missing_ok=True)
            return

        io = PDBIO()
        io.set_structure(structure)
        with open(out_path, "w") as fh:
            fh.writelines(extra_lines)
            io.save(fh, select=selector)
            fh.write("\n")
        self._saved.append({
            "output": out_path,
            "tmp": tmp,
            "ligand_res": lig_resnames,
            "chains": pocket.chains
        })
        logger.debug(f"Saved: {out_path}")


class ProteinAnalyzer:
    def __init__(
        self,
        interaction_distance=4.5,
        ligand_cluster_distance=0.5,
        rmsd_threshold=2.0,
        default_bond_distance=1.5,
        short_peptide_length=10,
        ligand_rmsd_threshold=0.5,
        overlap_distance=0.5,
        limit_low=3,
        limit_high=5,
        protect_distance=3.0,
    ):
        self.extractor = LigandPocketExtractor(
            interaction_distance,
            ligand_cluster_distance,
            default_bond_distance,
            short_peptide_length,
        )
        self.writer = PocketWriter(
            rmsd_threshold,
            ligand_rmsd_threshold,
            ligand_cluster_distance,
            default_bond_distance,
        )
        self.overlap_distance = overlap_distance
        self.limit_low = limit_low
        self.limit_high = limit_high
        self.protect_distance = protect_distance

    @staticmethod
    def _read_extra_lines(pdb_filepath: Path):
        other = []
        with open(pdb_filepath) as fh:
            for line in fh:
                if not line.startswith(("ATOM", "HETATM", "END", "MASTER", "TER", "CONECT", "ANISOU")):
                    other.append(line)
        return other

    @staticmethod
    def _min_dist(r1, r2):
        a1 = np.array([a.coord for a in r1.get_atoms()])
        a2 = np.array([a.coord for a in r2.get_atoms()])
        return np.min(np.linalg.norm(a1[:, None, :] - a2[None, :, :], axis=-1))

    @staticmethod
    def _pocket_min_dist(p1, p2):
        a1 = np.array([a.coord for r in p1.ligands for a in r.get_atoms()])
        a2 = np.array([a.coord for r in p2.ligands for a in r.get_atoms()])
        return np.min(np.linalg.norm(a1[:, None, :] - a2[None, :, :], axis=-1))

    def _split_overlapping(self, pocket, prot_atoms):

        ligs = [r for r in pocket.ligands if r.get_resname() != "HOH"]
        if len(ligs) < 2:
            return [pocket]

        overlapped = {
            (i, j)
            for i in range(len(ligs))
            for j in range(i + 1, len(ligs))
            if self._min_dist(ligs[i], ligs[j]) < self.overlap_distance
        }
        if not overlapped:
            return [pocket]

        others = [r for r in ligs if all((ligs.index(r), k) not in overlapped and
                                        (k, ligs.index(r)) not in overlapped for k in range(len(ligs)))]

        pockets = []
        for lig in {ligs[i] for i, _ in overlapped}.union({ligs[j] for _, j in overlapped}):
            lig_atoms = [a for a in lig.get_atoms()]
            btype = self.extractor._get_pocket_bond_type(lig_atoms, prot_atoms)
            pockets.append(Pocket([lig] + others, pocket.chains, btype))
        return pockets

    def _filter_overabundant(self, pockets):
        counts = {}
        for p in pockets:
            for n in {r.get_resname() for r in p.ligands if r.get_resname() != "HOH"}:
                counts[n] = counts.get(n, 0) + 1
        if not counts:
            return pockets
        min_count = min(counts.values())
        limit = self.limit_low if min_count <= 2 else self.limit_high
        abundant = {n for n, c in counts.items() if c > limit}
        if not abundant:
            return pockets
        rare_pockets = [
            p for p in pockets
            if not {r.get_resname() for r in p.ligands if r.get_resname() != "HOH"}.issubset(abundant)
        ]
        kept, removed = [], 0
        for p in pockets:
            names = {r.get_resname() for r in p.ligands if r.get_resname() != "HOH"}
            if names and names.issubset(abundant):
                close_to_rare = any(self._pocket_min_dist(p, rp) < self.protect_distance for rp in rare_pockets)
                if not close_to_rare:
                    removed += 1
                    continue
            kept.append(p)
        logger.debug(
            f"Overabundant filter (min {min_count}, limit {limit}, protect {self.protect_distance} Å): "
            f"removed {removed} pockets"
        )
        return kept

    def analyze(self, pdb_filepath, output_directory="separated_complexes"):
        pdb_filepath = Path(pdb_filepath)
        out_dir = Path(output_directory)
        out_dir.mkdir(exist_ok=True)
        logger.debug(f"Start: {pdb_filepath}")
        extra = self._read_extra_lines(pdb_filepath)
        structure = PDBParser(QUIET=True).get_structure("pdb", pdb_filepath)
        raw = self.extractor.extract(structure)
        prot_atoms = [a for a in structure.get_atoms() if a.get_parent().id[0] == " "]
        pockets = []
        for p in raw:
            splitted = self._split_overlapping(p, prot_atoms)
            pockets.extend(splitted)
        pockets = self._filter_overabundant(pockets)
        logger.debug(f"Total pockets to export: {len(pockets)}")
        for p in pockets:
            self.writer.save(structure, p, out_dir, extra, pdb_filepath.stem)
        logger.debug("Done")


def analyze_protein(
    pdb_filepath,
    output_directory="separated_complexes",
    interaction_distance=4.5,
    ligand_cluster_distance=1.5,
    rmsd_threshold=2.0,
    default_bond_distance=1.5,
    short_peptide_length=8,
    ligand_rmsd_threshold=1.0,
    overlap_distance=0.6,
):
    analyzer = ProteinAnalyzer(
        interaction_distance,
        ligand_cluster_distance,
        rmsd_threshold,
        default_bond_distance,
        short_peptide_length,
        ligand_rmsd_threshold,
        overlap_distance,
    )
    analyzer.analyze(pdb_filepath, output_directory)

# %%
# !rm -r test

# %%
Path('test').mkdir(exist_ok=True)
analyze_protein('/home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/1qjj.pdb', 'test/separated_complexes')
# Out:
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/1qjj.pdb
# Chain A has 376 residues. Num_std=200
# Chain B has 6 residues. Num_std=3
# Candidate residues: 7
# DEBUG: Atoms near HOA:N within 5.0 Å:
#   B/GLY303/O = 2.259 Å
#   B/HOA304/N = 0.000 Å
#   A/ZN250/ZN = 2.851 Å
#   B/HOA304/O = 1.398 Å
#   B/HOA304/HO = 1.973 Å
#   B/GLY303/CA = 2.415 Å
#   B/GLY303/C = 1.325 Å
#   A/HOH2139/H2 = 2.976 Å
#   B/HOA304/HN1 = 0.982 Å
#   A/CYS64/O = 2.839 Å
#   A/TYR149/HH = 2.761 Å
# DEBUG: Atoms near HOA:O within 5.0 Å:
#   B/GLY303/O = 2.710 Å
#   B/HOA304/N = 1.398 Å
#   A/ZN250/ZN = 2.129 Å
#   B/HOA304/O = 0.000 Å
#   B/HOA304/HO = 0.980 Å
#   A/GLU93/OE2 = 2.474 Å
#   A/HIS92/NE2 = 2.884 Å
#   B/GLY303/C = 2.357 Å
#   B/HOA304/HN1 = 2.097 Å
#   A/TYR149/OH = 2.979 Å
#   A/TYR149/HH = 2.181 Å
#   B/HOH2002/O = 2.900 Å
# DEBUG: Atoms near HOA:HN1 within 5.0 Å:
#   B/HOA304/N = 0.982 Å
#   B/HOA304/O = 2.097 Å
#   B/HOA304/HO = 2.338 Å
#   B/GLY303/CA = 2.499 Å
#   B/GLY303/C = 1.981 Å
#   B/HOA304/HN1 = 0.000 Å
#   A/CYS64/O = 1.866 Å
#   A/CYS64/C = 2.892 Å
# DEBUG: Atoms near HOA:HO within 5.0 Å:
#   B/HOA304/N = 1.973 Å
#   A/ZN250/ZN = 2.889 Å
#   B/HOA304/O = 0.980 Å
#   B/HOA304/HO = 0.000 Å
#   A/GLU93/OE2 = 2.184 Å
#   B/HOA304/HN1 = 2.338 Å
#   A/TYR149/HH = 2.125 Å
#   B/HOH2002/O = 2.000 Å
#   B/HOH2002/H1 = 2.362 Å
#   B/HOH2002/H2 = 2.822 Å
# New pocket with residues ['ZN', 'PRO', 'LEU', 'GLY', 'HOA'] -> bond=coord, chains={'A'}
# New pocket with residues ['HOH'] -> bond=, chains={'A'}
# New pocket with residues ['HOH'] -> bond=, chains={'A'}
# Pockets found: 3
# Total pockets to export: 3
# save: pocket has ligands {'LEU', 'GLY', 'PRO', 'HOA', 'ZN'}, bond_type=coord
# save: multiple ligands ['HOA', 'ZN', 'GLY', 'LEU', 'PRO'], checking connectivity...
# save: minimal distance among ligands in pocket is 1.325
# _ligands_connected: Checking ZN-PRO : ZN-N, dist=10.588, thr=2.16
# _ligands_connected: Checking ZN-PRO : ZN-CA, dist=9.440, thr=1.5
# _ligands_connected: Checking ZN-PRO : ZN-C, dist=8.277, thr=1.5
# _ligands_connected: Checking ZN-PRO : ZN-O, dist=8.603, thr=2.22
# _ligands_connected: Checking ZN-PRO : ZN-CB, dist=9.346, thr=1.5
# _ligands_connected: Checking ZN-PRO : ZN-CG, dist=9.902, thr=1.5
# _ligands_connected: Checking ZN-PRO : ZN-CD, dist=10.990, thr=1.5
# _ligands_connected: Checking ZN-PRO : ZN-H2, dist=11.435, thr=1.5
# _ligands_connected: Checking ZN-PRO : ZN-H3, dist=10.291, thr=1.5
# _ligands_connected: Checking ZN-LEU : ZN-N, dist=7.087, thr=2.16
# _ligands_connected: Checking ZN-LEU : ZN-CA, dist=5.996, thr=1.5
# _ligands_connected: Checking ZN-LEU : ZN-C, dist=4.997, thr=1.5
# _ligands_connected: Checking ZN-LEU : ZN-O, dist=4.890, thr=2.22
# _ligands_connected: Checking ZN-LEU : ZN-CB, dist=5.602, thr=1.5
# _ligands_connected: Checking ZN-LEU : ZN-CG, dist=5.306, thr=1.5
# _ligands_connected: Checking ZN-LEU : ZN-CD1, dist=6.726, thr=1.5
# _ligands_connected: Checking ZN-LEU : ZN-CD2, dist=4.451, thr=1.5
# _ligands_connected: Checking ZN-LEU : ZN-H, dist=7.038, thr=1.5
# _ligands_connected: Checking ZN-GLY : ZN-N, dist=4.764, thr=2.16
# _ligands_connected: Checking ZN-GLY : ZN-CA, dist=4.278, thr=1.5
# _ligands_connected: Checking ZN-GLY : ZN-C, dist=2.797, thr=1.5
# _ligands_connected: Checking ZN-GLY : ZN-O, dist=2.112, thr=2.22
# _ligands_connected: FOUND BOND between ZN and GLY
# save: LIGANDS ZN and GLY are connected -> union them
# _ligands_connected: Checking ZN-HOA : ZN-N, dist=2.851, thr=2.16
# _ligands_connected: Checking ZN-HOA : ZN-O, dist=2.129, thr=2.22
# _ligands_connected: FOUND BOND between ZN and HOA
# save: LIGANDS ZN and HOA are connected -> union them
# _ligands_connected: Checking PRO-LEU : N-N, dist=3.603, thr=1.5
# _ligands_connected: Checking PRO-LEU : N-CA, dist=4.750, thr=1.6
# _ligands_connected: Checking PRO-LEU : N-C, dist=5.655, thr=1.6
# _ligands_connected: Checking PRO-LEU : N-O, dist=5.958, thr=1.55
# _ligands_connected: Checking PRO-LEU : N-CB, dist=5.772, thr=1.6
# _ligands_connected: Checking PRO-LEU : N-CG, dist=6.815, thr=1.6
# _ligands_connected: Checking PRO-LEU : N-CD1, dist=6.807, thr=1.6
# _ligands_connected: Checking PRO-LEU : N-CD2, dist=8.151, thr=1.6
# _ligands_connected: Checking PRO-LEU : N-H, dist=3.977, thr=1.5
# _ligands_connected: Checking PRO-LEU : CA-N, dist=2.412, thr=1.6
# _ligands_connected: Checking PRO-LEU : CA-CA, dist=3.753, thr=1.54
# _ligands_connected: Checking PRO-LEU : CA-C, dist=4.659, thr=1.54
# _ligands_connected: Checking PRO-LEU : CA-O, dist=4.818, thr=1.63
# _ligands_connected: Checking PRO-LEU : CA-CB, dist=4.675, thr=1.54
# _ligands_connected: Checking PRO-LEU : CA-CG, dist=5.909, thr=1.54
# _ligands_connected: Checking PRO-LEU : CA-CD1, dist=6.111, thr=1.54
# _ligands_connected: Checking PRO-LEU : CA-CD2, dist=7.124, thr=1.54
# _ligands_connected: Checking PRO-LEU : CA-H, dist=2.581, thr=1.5
# _ligands_connected: Checking PRO-LEU : C-N, dist=1.325, thr=1.6
# _ligands_connected: FOUND BOND between PRO and LEU
# save: LIGANDS PRO and LEU are connected -> union them
# _ligands_connected: Checking PRO-GLY : N-N, dist=6.408, thr=1.5
# _ligands_connected: Checking PRO-GLY : N-CA, dist=7.526, thr=1.6
# _ligands_connected: Checking PRO-GLY : N-C, dist=8.610, thr=1.6
# _ligands_connected: Checking PRO-GLY : N-O, dist=8.909, thr=1.55
# _ligands_connected: Checking PRO-GLY : N-H, dist=6.393, thr=1.5
# _ligands_connected: Checking PRO-GLY : CA-N, dist=5.626, thr=1.6
# _ligands_connected: Checking PRO-GLY : CA-CA, dist=6.757, thr=1.54
# _ligands_connected: Checking PRO-GLY : CA-C, dist=7.665, thr=1.54
# _ligands_connected: Checking PRO-GLY : CA-O, dist=7.912, thr=1.63
# _ligands_connected: Checking PRO-GLY : CA-H, dist=5.758, thr=1.5
# _ligands_connected: Checking PRO-GLY : C-N, dist=4.275, thr=1.6
# _ligands_connected: Checking PRO-GLY : C-CA, dist=5.517, thr=1.54
# _ligands_connected: Checking PRO-GLY : C-C, dist=6.450, thr=1.54
# _ligands_connected: Checking PRO-GLY : C-O, dist=6.624, thr=1.63
# _ligands_connected: Checking PRO-GLY : C-H, dist=4.308, thr=1.5
# _ligands_connected: Checking PRO-GLY : O-N, dist=4.228, thr=1.55
# _ligands_connected: Checking PRO-GLY : O-CA, dist=5.496, thr=1.63
# _ligands_connected: Checking PRO-GLY : O-C, dist=6.596, thr=1.63
# _ligands_connected: Checking PRO-GLY : O-O, dist=6.767, thr=1.5
# _ligands_connected: Checking PRO-GLY : O-H, dist=4.013, thr=1.5
# _ligands_connected: Checking PRO-GLY : CB-N, dist=5.722, thr=1.6
# _ligands_connected: Checking PRO-GLY : CB-CA, dist=6.603, thr=1.54
# _ligands_connected: Checking PRO-GLY : CB-C, dist=7.488, thr=1.54
# _ligands_connected: Checking PRO-GLY : CB-O, dist=7.927, thr=1.63
# _ligands_connected: Checking PRO-GLY : CB-H, dist=6.076, thr=1.5
# _ligands_connected: Checking PRO-GLY : CG-N, dist=5.849, thr=1.6
# _ligands_connected: Checking PRO-GLY : CG-CA, dist=6.595, thr=1.54
# _ligands_connected: Checking PRO-GLY : CG-C, dist=7.707, thr=1.54
# _ligands_connected: Checking PRO-GLY : CG-O, dist=8.302, thr=1.63
# _ligands_connected: Checking PRO-GLY : CG-H, dist=6.134, thr=1.5
# _ligands_connected: Checking PRO-GLY : CD-N, dist=6.698, thr=1.6
# _ligands_connected: Checking PRO-GLY : CD-CA, dist=7.605, thr=1.54
# _ligands_connected: Checking PRO-GLY : CD-C, dist=8.792, thr=1.54
# _ligands_connected: Checking PRO-GLY : CD-O, dist=9.283, thr=1.63
# _ligands_connected: Checking PRO-GLY : CD-H, dist=6.781, thr=1.5
# _ligands_connected: Checking PRO-GLY : H2-N, dist=7.355, thr=1.5
# _ligands_connected: Checking PRO-GLY : H2-CA, dist=8.514, thr=1.5
# _ligands_connected: Checking PRO-GLY : H2-C, dist=9.558, thr=1.5
# _ligands_connected: Checking PRO-GLY : H2-O, dist=9.801, thr=1.5
# _ligands_connected: Checking PRO-GLY : H2-H, dist=7.310, thr=1.5
# _ligands_connected: Checking PRO-GLY : H3-N, dist=5.943, thr=1.5
# _ligands_connected: Checking PRO-GLY : H3-CA, dist=7.125, thr=1.5
# _ligands_connected: Checking PRO-GLY : H3-C, dist=8.264, thr=1.5
# _ligands_connected: Checking PRO-GLY : H3-O, dist=8.507, thr=1.5
# _ligands_connected: Checking PRO-GLY : H3-H, dist=5.785, thr=1.5
# _ligands_connected: Checking PRO-HOA : N-N, dist=9.405, thr=1.5
# _ligands_connected: Checking PRO-HOA : N-O, dist=10.534, thr=1.55
# _ligands_connected: Checking PRO-HOA : N-HN1, dist=9.292, thr=1.5
# _ligands_connected: Checking PRO-HOA : N-HO, dist=11.300, thr=1.5
# _ligands_connected: Checking PRO-HOA : CA-N, dist=8.420, thr=1.6
# _ligands_connected: Checking PRO-HOA : CA-O, dist=9.451, thr=1.63
# _ligands_connected: Checking PRO-HOA : CA-HN1, dist=8.375, thr=1.5
# _ligands_connected: Checking PRO-HOA : CA-HO, dist=10.252, thr=1.5
# _ligands_connected: Checking PRO-HOA : C-N, dist=7.339, thr=1.6
# _ligands_connected: Checking PRO-HOA : C-O, dist=8.398, thr=1.63
# _ligands_connected: Checking PRO-HOA : C-HN1, dist=7.378, thr=1.5
# _ligands_connected: Checking PRO-HOA : C-HO, dist=9.225, thr=1.5
# _ligands_connected: Checking PRO-HOA : O-N, dist=7.587, thr=1.55
# _ligands_connected: Checking PRO-HOA : O-O, dist=8.732, thr=1.5
# _ligands_connected: Checking PRO-HOA : O-HN1, dist=7.613, thr=1.5
# _ligands_connected: Checking PRO-HOA : O-HO, dist=9.532, thr=1.5
# _ligands_connected: Checking PRO-HOA : CB-N, dist=8.027, thr=1.6
# _ligands_connected: Checking PRO-HOA : CB-O, dist=9.056, thr=1.63
# _ligands_connected: Checking PRO-HOA : CB-HN1, dist=7.846, thr=1.5
# _ligands_connected: Checking PRO-HOA : CB-HO, dist=9.781, thr=1.5
# _ligands_connected: Checking PRO-HOA : CG-N, dist=8.223, thr=1.6
# _ligands_connected: Checking PRO-HOA : CG-O, dist=9.394, thr=1.63
# _ligands_connected: Checking PRO-HOA : CG-HN1, dist=7.902, thr=1.5
# _ligands_connected: Checking PRO-HOA : CG-HO, dist=10.035, thr=1.5
# _ligands_connected: Checking PRO-HOA : CD-N, dist=9.447, thr=1.6
# _ligands_connected: Checking PRO-HOA : CD-O, dist=10.645, thr=1.63
# _ligands_connected: Checking PRO-HOA : CD-HN1, dist=9.180, thr=1.5
# _ligands_connected: Checking PRO-HOA : CD-HO, dist=11.323, thr=1.5
# _ligands_connected: Checking PRO-HOA : H2-N, dist=10.366, thr=1.5
# _ligands_connected: Checking PRO-HOA : H2-O, dist=11.460, thr=1.5
# _ligands_connected: Checking PRO-HOA : H2-HN1, dist=10.277, thr=1.5
# _ligands_connected: Checking PRO-HOA : H2-HO, dist=12.245, thr=1.5
# _ligands_connected: Checking PRO-HOA : H3-N, dist=9.162, thr=1.5
# _ligands_connected: Checking PRO-HOA : H3-O, dist=10.322, thr=1.5
# _ligands_connected: Checking PRO-HOA : H3-HN1, dist=9.093, thr=1.5
# _ligands_connected: Checking PRO-HOA : H3-HO, dist=11.098, thr=1.5
# _ligands_connected: Checking LEU-GLY : N-N, dist=3.546, thr=1.5
# _ligands_connected: Checking LEU-GLY : N-CA, dist=4.776, thr=1.6
# _ligands_connected: Checking LEU-GLY : N-C, dist=5.478, thr=1.6
# _ligands_connected: Checking LEU-GLY : N-O, dist=5.577, thr=1.55
# _ligands_connected: Checking LEU-GLY : N-H, dist=3.762, thr=1.5
# _ligands_connected: Checking LEU-GLY : CA-N, dist=2.411, thr=1.6
# _ligands_connected: Checking LEU-GLY : CA-CA, dist=3.773, thr=1.54
# _ligands_connected: Checking LEU-GLY : CA-C, dist=4.402, thr=1.54
# _ligands_connected: Checking LEU-GLY : CA-O, dist=4.350, thr=1.63
# _ligands_connected: Checking LEU-GLY : CA-H, dist=2.519, thr=1.5
# _ligands_connected: Checking LEU-GLY : C-N, dist=1.332, thr=1.6
# _ligands_connected: FOUND BOND between LEU and GLY
# save: LIGANDS LEU and GLY are connected -> union them
# _ligands_connected: Checking LEU-HOA : N-N, dist=6.345, thr=1.5
# _ligands_connected: Checking LEU-HOA : N-O, dist=7.297, thr=1.55
# _ligands_connected: Checking LEU-HOA : N-HN1, dist=6.481, thr=1.5
# _ligands_connected: Checking LEU-HOA : N-HO, dist=8.162, thr=1.5
# _ligands_connected: Checking LEU-HOA : CA-N, dist=5.443, thr=1.6
# _ligands_connected: Checking LEU-HOA : CA-O, dist=6.383, thr=1.63
# _ligands_connected: Checking LEU-HOA : CA-HN1, dist=5.717, thr=1.5
# _ligands_connected: Checking LEU-HOA : CA-HO, dist=7.274, thr=1.5
# _ligands_connected: Checking LEU-HOA : C-N, dist=3.997, thr=1.6
# _ligands_connected: Checking LEU-HOA : C-O, dist=5.034, thr=1.63
# _ligands_connected: Checking LEU-HOA : C-HN1, dist=4.209, thr=1.5
# _ligands_connected: Checking LEU-HOA : C-HO, dist=5.878, thr=1.5
# _ligands_connected: Checking LEU-HOA : O-N, dist=3.684, thr=1.55
# _ligands_connected: Checking LEU-HOA : O-O, dist=4.636, thr=1.5
# _ligands_connected: Checking LEU-HOA : O-HN1, dist=3.791, thr=1.5
# _ligands_connected: Checking LEU-HOA : O-HO, dist=5.448, thr=1.5
# _ligands_connected: Checking LEU-HOA : CB-N, dist=5.807, thr=1.6
# _ligands_connected: Checking LEU-HOA : CB-O, dist=6.472, thr=1.63
# _ligands_connected: Checking LEU-HOA : CB-HN1, dist=6.298, thr=1.5
# _ligands_connected: Checking LEU-HOA : CB-HO, dist=7.430, thr=1.5
# _ligands_connected: Checking LEU-HOA : CG-N, dist=5.863, thr=1.6
# _ligands_connected: Checking LEU-HOA : CG-O, dist=6.462, thr=1.63
# _ligands_connected: Checking LEU-HOA : CG-HN1, dist=6.478, thr=1.5
# _ligands_connected: Checking LEU-HOA : CG-HO, dist=7.401, thr=1.5
# _ligands_connected: Checking LEU-HOA : CD1-N, dist=7.332, thr=1.6
# _ligands_connected: Checking LEU-HOA : CD1-O, dist=7.958, thr=1.63
# _ligands_connected: Checking LEU-HOA : CD1-HN1, dist=7.918, thr=1.5
# _ligands_connected: Checking LEU-HOA : CD1-HO, dist=8.884, thr=1.5
# _ligands_connected: Checking LEU-HOA : CD2-N, dist=5.717, thr=1.6
# _ligands_connected: Checking LEU-HOA : CD2-O, dist=5.998, thr=1.63
# _ligands_connected: Checking LEU-HOA : CD2-HN1, dist=6.494, thr=1.5
# _ligands_connected: Checking LEU-HOA : CD2-HO, dist=6.938, thr=1.5
# _ligands_connected: Checking LEU-HOA : H-N, dist=6.383, thr=1.5
# _ligands_connected: Checking LEU-HOA : H-O, dist=7.225, thr=1.5
# _ligands_connected: Checking LEU-HOA : H-HN1, dist=6.522, thr=1.5
# _ligands_connected: Checking LEU-HOA : H-HO, dist=8.091, thr=1.5
# _ligands_connected: Checking GLY-HOA : N-N, dist=3.562, thr=1.5
# _ligands_connected: Checking GLY-HOA : N-O, dist=4.725, thr=1.55
# _ligands_connected: Checking GLY-HOA : N-HN1, dist=3.781, thr=1.5
# _ligands_connected: Checking GLY-HOA : N-HO, dist=5.494, thr=1.5
# _ligands_connected: Checking GLY-HOA : CA-N, dist=2.415, thr=1.6
# _ligands_connected: Checking GLY-HOA : CA-O, dist=3.723, thr=1.63
# _ligands_connected: Checking GLY-HOA : CA-HN1, dist=2.499, thr=1.5
# _ligands_connected: Checking GLY-HOA : CA-HO, dist=4.345, thr=1.5
# _ligands_connected: Checking GLY-HOA : C-N, dist=1.325, thr=1.6
# _ligands_connected: FOUND BOND between GLY and HOA
# save: LIGANDS GLY and HOA are connected -> union them
# save: final lig_code=GLYHOALEUPROZN
# Duplicate check for: 1qjj_GLYHOALEUPROZN_chains_A_coord.pdb
# Saved: test/separated_complexes/1qjj_GLYHOALEUPROZN_chains_A_coord.pdb
# Done

# %%
from pathlib import Path
from tqdm.auto import tqdm
Path('test').mkdir(exist_ok=True)
test_data_dir = Path('/home/nikolenko/work/Projects/LPCE/lpce/tests/test_data')
pdb_files = list(test_data_dir.glob('*.pdb'))
for pdb_file in tqdm(pdb_files, desc='Processing PDB files', total=len(pdb_files)):
    analyze_protein(
        str(pdb_file),
        f'test/separated_complexes_{pdb_file.stem}'
    )
# Out:
# Processing PDB files:   0%|          | 0/24 [00:00<?, ?it/s]
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/4x6h.pdb
# Candidate residues: 8
#    -> pocket has NO bond_type
# New pocket with residues ['3XT', 'I37'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
# Pockets found: 7
#    -> pocket has NO bond_type
#    -> pocket has NO bond_type
# Overabundant filter (min 1, limit 3, protect 3.0 Å): removed 6 pockets
# Total pockets to export: 2
# save: pocket has ligands {'3XT'}, bond_type=
# save: single ligand 3XT
# Duplicate check for: 4x6h_3XT_chains_A.pdb
# Saved: test/separated_complexes_4x6h/4x6h_3XT_chains_A.pdb
# save: pocket has ligands {'I37'}, bond_type=
# save: single ligand I37
# Duplicate check for: 4x6h_I37_chains_A.pdb
# Saved: test/separated_complexes_4x6h/4x6h_I37_chains_A.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/1bm6.pdb
# extract: multiple models, using first model.
# Candidate residues: 7
#    -> pocket has NO bond_type
# New pocket with residues ['ZN'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['ZN'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['CA'] -> bond=, chains={'A'}
#    -> recognized as COORD bond
#    -> pocket has COORD bond
# New pocket with residues ['CA'] -> bond=coord, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['HAV', '3MP', 'MSB'] -> bond=, chains={'A'}
# Pockets found: 5
# Total pockets to export: 5
# save: pocket has ligands {'ZN'}, bond_type=
# save: single ligand ZN
# Duplicate check for: 1bm6_ZN_chains_A.pdb
# Saved: test/separated_complexes_1bm6/1bm6_ZN_chains_A.pdb
# save: pocket has ligands {'ZN'}, bond_type=
# save: single ligand ZN
# Duplicate check for: 1bm6_ZN_chains_A_v2.pdb
#     ligand RMSD -> graph mode matched. RMSD=7.028
#     Ligand RMSD  = 7.028 Å (thr 1.0)
# Saved: test/separated_complexes_1bm6/1bm6_ZN_chains_A_v2.pdb
# save: pocket has ligands {'CA'}, bond_type=
# save: single ligand CA
# Duplicate check for: 1bm6_CA_chains_A.pdb
# Saved: test/separated_complexes_1bm6/1bm6_CA_chains_A.pdb
# save: pocket has ligands {'CA'}, bond_type=coord
# save: single ligand CA
# Duplicate check for: 1bm6_CA_chains_A_coord.pdb
#     ligand RMSD -> graph mode matched. RMSD=12.594
#     Ligand RMSD  = 12.594 Å (thr 1.0)
# Saved: test/separated_complexes_1bm6/1bm6_CA_chains_A_coord.pdb
# save: pocket has ligands {'3MP', 'MSB', 'HAV'}, bond_type=
# save: multiple ligands ['3MP', 'HAV', 'MSB'], checking connectivity...
# save: minimal distance among ligands in pocket is 1.494
# _ligands_connected: Checking HAV-3MP : NA-CB, dist=1.494, thr=1.5
# _ligands_connected: FOUND BOND between HAV and 3MP
# save: LIGANDS HAV and 3MP are connected -> union them
# _ligands_connected: Checking HAV-MSB : NA-S, dist=1.630, thr=1.7
# _ligands_connected: FOUND BOND between HAV and MSB
# save: LIGANDS HAV and MSB are connected -> union them
# _ligands_connected: Checking 3MP-MSB : CB-S, dist=2.637, thr=1.8
# _ligands_connected: Checking 3MP-MSB : CB-OB1, dist=3.063, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CB-OB2, dist=3.787, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CB-CG, dist=3.140, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CB-CD1, dist=4.245, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CB-CD2, dist=3.216, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CB-CE1, dist=5.178, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CB-CE2, dist=4.370, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CB-CZ, dist=5.230, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CB-OH, dist=6.468, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CB-CH, dist=7.585, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CB-HD1, dist=4.654, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CB-HD2, dist=2.836, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CB-HE1, dist=6.111, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CB-HE2, dist=4.869, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CB-HH1, dist=8.464, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CB-HH2, dist=7.815, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CB-HH3, dist=7.543, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CG-S, dist=3.476, thr=1.8
# _ligands_connected: Checking 3MP-MSB : CG-OB1, dist=3.313, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CG-OB2, dist=4.642, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CG-CG, dist=4.297, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CG-CD1, dist=5.540, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CG-CD2, dist=4.199, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CG-CE1, dist=6.503, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CG-CE2, dist=5.403, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CG-CZ, dist=6.446, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CG-OH, dist=7.670, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CG-CH, dist=8.806, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CG-HD1, dist=5.941, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CG-HD2, dist=3.487, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CG-HE1, dist=7.483, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CG-HE2, dist=5.727, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CG-HH1, dist=9.638, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CG-HH2, dist=9.135, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CG-HH3, dist=8.695, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD1-S, dist=3.467, thr=1.8
# _ligands_connected: Checking 3MP-MSB : CD1-OB1, dist=2.941, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CD1-OB2, dist=4.447, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CD1-CG, dist=4.712, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD1-CD1, dist=5.962, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD1-CD2, dist=4.817, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD1-CE1, dist=7.080, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD1-CE2, dist=6.146, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD1-CZ, dist=7.159, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD1-OH, dist=8.452, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CD1-CH, dist=9.469, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD1-HD1, dist=6.221, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD1-HD2, dist=4.105, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD1-HE1, dist=8.043, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD1-HE2, dist=6.544, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD1-HH1, dist=10.336, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD1-HH2, dist=9.808, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD1-HH3, dist=9.213, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD2-S, dist=4.799, thr=1.8
# _ligands_connected: Checking 3MP-MSB : CD2-OB1, dist=4.570, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CD2-OB2, dist=6.014, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CD2-CG, dist=5.372, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD2-CD1, dist=6.618, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD2-CD2, dist=4.996, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD2-CE1, dist=7.419, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD2-CE2, dist=6.010, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD2-CZ, dist=7.157, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD2-OH, dist=8.257, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CD2-CH, dist=9.502, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CD2-HD1, dist=7.124, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD2-HD2, dist=4.170, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD2-HE1, dist=8.417, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD2-HE2, dist=6.112, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD2-HH1, dist=10.246, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD2-HH2, dist=9.887, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CD2-HH3, dist=9.485, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CE1-S, dist=4.777, thr=1.8
# _ligands_connected: Checking 3MP-MSB : CE1-OB1, dist=4.029, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CE1-OB2, dist=5.709, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CE1-CG, dist=6.008, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CE1-CD1, dist=7.295, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CE1-CD2, dist=5.983, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CE1-CE1, dist=8.385, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CE1-CE2, dist=7.271, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CE1-CZ, dist=8.376, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CE1-OH, dist=9.636, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CE1-CH, dist=10.674, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CE1-HD1, dist=7.571, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CE1-HD2, dist=5.148, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CE1-HE1, dist=9.371, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CE1-HE2, dist=7.545, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CE1-HH1, dist=11.498, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CE1-HH2, dist=11.075, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CE1-HH3, dist=10.395, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CZ-S, dist=5.775, thr=1.8
# _ligands_connected: Checking 3MP-MSB : CZ-OB1, dist=5.093, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CZ-OB2, dist=6.840, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CZ-CG, dist=6.769, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CZ-CD1, dist=8.090, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CZ-CD2, dist=6.513, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CZ-CE1, dist=9.054, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CZ-CE2, dist=7.674, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CZ-CZ, dist=8.873, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CZ-OH, dist=10.044, thr=1.43
# _ligands_connected: Checking 3MP-MSB : CZ-CH, dist=11.192, thr=1.54
# _ligands_connected: Checking 3MP-MSB : CZ-HD1, dist=8.482, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CZ-HD2, dist=5.583, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CZ-HE1, dist=10.072, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CZ-HE2, dist=7.781, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CZ-HH1, dist=11.948, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CZ-HH2, dist=11.638, thr=1.5
# _ligands_connected: Checking 3MP-MSB : CZ-HH3, dist=11.008, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-S, dist=5.809, thr=1.7
# _ligands_connected: Checking 3MP-MSB : NE2-OB1, dist=5.339, thr=1.25
# _ligands_connected: Checking 3MP-MSB : NE2-OB2, dist=6.990, thr=1.25
# _ligands_connected: Checking 3MP-MSB : NE2-CG, dist=6.524, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-CD1, dist=7.819, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-CD2, dist=6.113, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-CE1, dist=8.649, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-CE2, dist=7.137, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-CZ, dist=8.351, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-OH, dist=9.438, thr=1.25
# _ligands_connected: Checking 3MP-MSB : NE2-CH, dist=10.676, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-HD1, dist=8.309, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-HD2, dist=5.192, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-HE1, dist=9.667, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-HE2, dist=7.155, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-HH1, dist=11.390, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-HH2, dist=11.116, thr=1.5
# _ligands_connected: Checking 3MP-MSB : NE2-HH3, dist=10.613, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-S, dist=3.466, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-OB1, dist=4.095, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-OB2, dist=4.436, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-CG, dist=3.776, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-CD1, dist=4.669, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-CD2, dist=3.854, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-CE1, dist=5.486, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-CE2, dist=4.806, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-CZ, dist=5.545, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-OH, dist=6.691, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-CH, dist=7.860, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-HD1, dist=5.033, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-HD2, dist=3.606, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-HE1, dist=6.336, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-HE2, dist=5.272, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-HH1, dist=8.725, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-HH2, dist=7.998, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB1-HH3, dist=7.951, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-S, dist=2.630, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-OB1, dist=2.977, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-OB2, dist=3.938, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-CG, dist=2.571, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-CD1, dist=3.762, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-CD2, dist=2.280, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-CE1, dist=4.514, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-CE2, dist=3.374, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-CZ, dist=4.358, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-OH, dist=5.562, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-CH, dist=6.724, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-HD1, dist=4.394, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-HD2, dist=1.856, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-HE1, dist=5.515, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-HE2, dist=3.808, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-HH1, dist=7.554, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-HH2, dist=7.048, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HB2-HH3, dist=6.692, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-S, dist=2.805, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-OB1, dist=2.282, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-OB2, dist=3.577, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-CG, dist=4.309, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-CD1, dist=5.468, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-CD2, dist=4.685, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-CE1, dist=6.695, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-CE2, dist=6.075, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-CZ, dist=6.953, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-OH, dist=8.298, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-CH, dist=9.192, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-HD1, dist=5.588, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-HD2, dist=4.142, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-HE1, dist=7.605, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-HE2, dist=6.617, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-HH1, dist=10.110, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-HH2, dist=9.480, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD1-HH3, dist=8.854, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-S, dist=5.206, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-OB1, dist=5.171, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-OB2, dist=6.445, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-CG, dist=5.474, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-CD1, dist=6.633, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-CD2, dist=4.965, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-CE1, dist=7.274, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-CE2, dist=5.785, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-CZ, dist=6.904, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-OH, dist=7.895, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-CH, dist=9.208, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-HD1, dist=7.215, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-HD2, dist=4.218, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-HE1, dist=8.246, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-HE2, dist=5.796, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-HH1, dist=9.904, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-HH2, dist=9.579, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HD2-HH3, dist=9.311, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-S, dist=5.218, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-OB1, dist=4.336, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-OB2, dist=5.980, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-CG, dist=6.596, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-CD1, dist=7.848, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-CD2, dist=6.675, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-CE1, dist=9.003, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-CE2, dist=8.001, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-CZ, dist=9.071, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-OH, dist=10.358, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-CH, dist=11.318, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-HD1, dist=8.040, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-HD2, dist=5.873, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-HE1, dist=9.966, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-HE2, dist=8.315, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-HH1, dist=12.156, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-HH2, dist=11.720, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HE1-HH3, dist=10.955, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-S, dist=6.771, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-OB1, dist=5.993, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-OB2, dist=7.800, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-CG, dist=7.795, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-CD1, dist=9.128, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-CD2, dist=7.507, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-CE1, dist=10.091, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-CE2, dist=8.649, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-CZ, dist=9.879, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-OH, dist=11.033, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-CH, dist=12.179, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-HD1, dist=9.515, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-HD2, dist=6.544, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-HE1, dist=11.116, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-HE2, dist=8.701, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-HH1, dist=12.911, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-HH2, dist=12.657, thr=1.5
# _ligands_connected: Checking 3MP-MSB : HZ-HH3, dist=11.973, thr=1.5
# save: final lig_code=3MPHAVMSB
# Duplicate check for: 1bm6_3MPHAVMSB_chains_A.pdb
# Saved: test/separated_complexes_1bm6/1bm6_3MPHAVMSB_chains_A.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/5efn.pdb
# Candidate residues: 15
#    -> pocket has NO bond_type
# New pocket with residues ['ZN'] -> bond=, chains={'B'}
#    -> recognized as COORD bond
#    -> pocket has COORD bond
# New pocket with residues ['K'] -> bond=coord, chains={'B'}
#    -> recognized as COORD bond
#    -> pocket has COORD bond
# New pocket with residues ['K'] -> bond=coord, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['EDO'] -> bond=, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['EDO'] -> bond=, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['ARG', 'GLY', '5OL', 'MCM'] -> bond=, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['ZN'] -> bond=, chains={'A'}
#    -> recognized as COORD bond
#    -> pocket has COORD bond
# New pocket with residues ['K'] -> bond=coord, chains={'A'}
#    -> recognized as COORD bond
#    -> pocket has COORD bond
# New pocket with residues ['K'] -> bond=coord, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['EDO'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['5OL', 'MCM'] -> bond=, chains={'A'}
# Pockets found: 11
# Overabundant filter (min 1, limit 3, protect 3.0 Å): removed 4 pockets
# Total pockets to export: 7
# save: pocket has ligands {'ZN'}, bond_type=
# save: single ligand ZN
# Duplicate check for: 5efn_ZN_chains_B.pdb
# Saved: test/separated_complexes_5efn/5efn_ZN_chains_B.pdb
# save: pocket has ligands {'EDO'}, bond_type=
# save: single ligand EDO
# Duplicate check for: 5efn_EDO_chains_B.pdb
# Saved: test/separated_complexes_5efn/5efn_EDO_chains_B.pdb
# save: pocket has ligands {'EDO'}, bond_type=
# save: single ligand EDO
# Duplicate check for: 5efn_EDO_chains_B_v2.pdb
#     ligand RMSD -> graph mode matched. RMSD=25.900
#     Ligand RMSD  = 25.900 Å (thr 1.0)
# Saved: test/separated_complexes_5efn/5efn_EDO_chains_B_v2.pdb
# save: pocket has ligands {'MCM', '5OL', 'ARG', 'GLY'}, bond_type=
# save: multiple ligands ['5OL', 'MCM', 'ARG', 'GLY'], checking connectivity...
# save: minimal distance among ligands in pocket is 1.329
# _ligands_connected: Checking ARG-GLY : N-N, dist=2.691, thr=1.5
# _ligands_connected: Checking ARG-GLY : N-CA, dist=4.128, thr=1.5
# _ligands_connected: Checking ARG-GLY : N-C, dist=5.000, thr=1.5
# _ligands_connected: Checking ARG-GLY : N-O, dist=4.948, thr=1.25
# _ligands_connected: Checking ARG-GLY : CA-N, dist=2.436, thr=1.5
# _ligands_connected: Checking ARG-GLY : CA-CA, dist=3.805, thr=1.54
# _ligands_connected: Checking ARG-GLY : CA-C, dist=4.648, thr=1.54
# _ligands_connected: Checking ARG-GLY : CA-O, dist=4.826, thr=1.43
# _ligands_connected: Checking ARG-GLY : C-N, dist=1.329, thr=1.5
# _ligands_connected: FOUND BOND between ARG and GLY
# save: LIGANDS ARG and GLY are connected -> union them
# _ligands_connected: Checking ARG-5OL : N-CA, dist=7.216, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-N, dist=6.149, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-C, dist=7.901, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-O, dist=8.498, thr=1.25
# _ligands_connected: Checking ARG-5OL : N-C03, dist=8.341, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-C04, dist=9.537, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-C05, dist=10.653, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-C06, dist=11.928, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-N07, dist=12.988, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-C08, dist=14.204, thr=1.5
# _ligands_connected: Checking ARG-5OL : N-O02, dist=14.164, thr=1.25
# _ligands_connected: Checking ARG-5OL : N-O01, dist=14.669, thr=1.25
# _ligands_connected: Checking ARG-5OL : N-C11, dist=15.274, thr=1.5
# _ligands_connected: Checking ARG-5OL : CA-CA, dist=6.660, thr=1.54
# _ligands_connected: Checking ARG-5OL : CA-N, dist=5.587, thr=1.5
# _ligands_connected: Checking ARG-5OL : CA-C, dist=7.584, thr=1.54
# _ligands_connected: Checking ARG-5OL : CA-O, dist=8.265, thr=1.43
# _ligands_connected: Checking ARG-5OL : CA-C03, dist=7.599, thr=1.54
# _ligands_connected: Checking ARG-5OL : CA-C04, dist=8.817, thr=1.54
# _ligands_connected: Checking ARG-5OL : CA-C05, dist=9.796, thr=1.54
# _ligands_connected: Checking ARG-5OL : CA-C06, dist=11.095, thr=1.54
# _ligands_connected: Checking ARG-5OL : CA-N07, dist=12.067, thr=1.5
# _ligands_connected: Checking ARG-5OL : CA-C08, dist=13.292, thr=1.54
# _ligands_connected: Checking ARG-5OL : CA-O02, dist=13.205, thr=1.43
# _ligands_connected: Checking ARG-5OL : CA-O01, dist=13.867, thr=1.43
# _ligands_connected: Checking ARG-5OL : CA-C11, dist=14.305, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-CA, dist=5.359, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-N, dist=4.181, thr=1.5
# _ligands_connected: Checking ARG-5OL : C-C, dist=6.315, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-O, dist=7.125, thr=1.43
# _ligands_connected: Checking ARG-5OL : C-C03, dist=6.245, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-C04, dist=7.549, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-C05, dist=8.516, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-C06, dist=9.877, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-N07, dist=10.826, thr=1.5
# _ligands_connected: Checking ARG-5OL : C-C08, dist=12.101, thr=1.54
# _ligands_connected: Checking ARG-5OL : C-O02, dist=12.125, thr=1.43
# _ligands_connected: Checking ARG-5OL : C-O01, dist=12.670, thr=1.43
# _ligands_connected: Checking ARG-5OL : C-C11, dist=13.072, thr=1.54
# _ligands_connected: Checking ARG-5OL : O-CA, dist=5.189, thr=1.43
# _ligands_connected: Checking ARG-5OL : O-N, dist=4.020, thr=1.25
# _ligands_connected: Checking ARG-5OL : O-C, dist=6.335, thr=1.43
# _ligands_connected: Checking ARG-5OL : O-O, dist=7.238, thr=1.5
# _ligands_connected: Checking ARG-5OL : O-C03, dist=5.798, thr=1.43
# _ligands_connected: Checking ARG-5OL : O-C04, dist=7.137, thr=1.43
# _ligands_connected: Checking ARG-5OL : O-C05, dist=7.927, thr=1.43
# _ligands_connected: Checking ARG-5OL : O-C06, dist=9.326, thr=1.43
# _ligands_connected: Checking ARG-5OL : O-N07, dist=10.158, thr=1.25
# _ligands_connected: Checking ARG-5OL : O-C08, dist=11.454, thr=1.43
# _ligands_connected: Checking ARG-5OL : O-O02, dist=11.473, thr=1.5
# _ligands_connected: Checking ARG-5OL : O-O01, dist=12.131, thr=1.5
# _ligands_connected: Checking ARG-5OL : O-C11, dist=12.338, thr=1.43
# _ligands_connected: Checking ARG-5OL : CB-CA, dist=7.794, thr=1.54
# _ligands_connected: Checking ARG-5OL : CB-N, dist=6.642, thr=1.5
# _ligands_connected: Checking ARG-5OL : CB-C, dist=8.807, thr=1.54
# _ligands_connected: Checking ARG-5OL : CB-O, dist=9.582, thr=1.43
# _ligands_connected: Checking ARG-5OL : CB-C03, dist=8.564, thr=1.54
# _ligands_connected: Checking ARG-5OL : CB-C04, dist=9.842, thr=1.54
# _ligands_connected: Checking ARG-5OL : CB-C05, dist=10.679, thr=1.54
# _ligands_connected: Checking ARG-5OL : CB-C06, dist=12.023, thr=1.54
# _ligands_connected: Checking ARG-5OL : CB-N07, dist=12.880, thr=1.5
# _ligands_connected: Checking ARG-5OL : CB-C08, dist=14.129, thr=1.54
# _ligands_connected: Checking ARG-5OL : CB-O02, dist=14.026, thr=1.43
# _ligands_connected: Checking ARG-5OL : CB-O01, dist=14.814, thr=1.43
# _ligands_connected: Checking ARG-5OL : CB-C11, dist=15.046, thr=1.54
# _ligands_connected: Checking ARG-MCM : N-N, dist=8.094, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-CA, dist=8.959, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C2, dist=9.486, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C3, dist=10.519, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C4, dist=12.349, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C5, dist=12.838, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C6, dist=12.280, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C7, dist=11.058, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C8, dist=10.590, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C9, dist=9.550, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-C10, dist=13.060, thr=1.5
# _ligands_connected: Checking ARG-MCM : N-O1, dist=11.233, thr=1.25
# _ligands_connected: Checking ARG-MCM : N-O2, dist=13.063, thr=1.25
# _ligands_connected: Checking ARG-MCM : CA-N, dist=7.865, thr=1.5
# _ligands_connected: Checking ARG-MCM : CA-CA, dist=8.895, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C2, dist=9.548, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C3, dist=10.692, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C4, dist=12.685, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C5, dist=13.176, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C6, dist=12.547, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C7, dist=11.233, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C8, dist=10.665, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C9, dist=9.504, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-C10, dist=13.326, thr=1.54
# _ligands_connected: Checking ARG-MCM : CA-O1, dist=11.494, thr=1.43
# _ligands_connected: Checking ARG-MCM : CA-O2, dist=13.455, thr=1.43
# _ligands_connected: Checking ARG-MCM : C-N, dist=6.520, thr=1.5
# _ligands_connected: Checking ARG-MCM : C-CA, dist=7.599, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C2, dist=8.370, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C3, dist=9.544, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C4, dist=11.656, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C5, dist=12.087, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C6, dist=11.379, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C7, dist=10.022, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C8, dist=9.370, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C9, dist=8.159, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-C10, dist=12.125, thr=1.54
# _ligands_connected: Checking ARG-MCM : C-O1, dist=10.446, thr=1.43
# _ligands_connected: Checking ARG-MCM : C-O2, dist=12.502, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-N, dist=6.556, thr=1.25
# _ligands_connected: Checking ARG-MCM : O-CA, dist=7.739, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C2, dist=8.635, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C3, dist=9.860, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C4, dist=12.079, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C5, dist=12.473, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C6, dist=11.690, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C7, dist=10.286, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C8, dist=9.531, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C9, dist=8.249, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-C10, dist=12.393, thr=1.43
# _ligands_connected: Checking ARG-MCM : O-O1, dist=10.842, thr=1.5
# _ligands_connected: Checking ARG-MCM : O-O2, dist=12.978, thr=1.5
# _ligands_connected: Checking ARG-MCM : CB-N, dist=9.008, thr=1.5
# _ligands_connected: Checking ARG-MCM : CB-CA, dist=10.062, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C2, dist=10.825, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C3, dist=11.959, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C4, dist=14.008, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C5, dist=14.418, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C6, dist=13.706, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C7, dist=12.393, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C8, dist=11.715, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C9, dist=10.547, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-C10, dist=14.384, thr=1.54
# _ligands_connected: Checking ARG-MCM : CB-O1, dist=12.833, thr=1.43
# _ligands_connected: Checking ARG-MCM : CB-O2, dist=14.826, thr=1.43
# _ligands_connected: Checking GLY-5OL : N-CA, dist=4.779, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-N, dist=3.564, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-C, dist=5.477, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-O, dist=6.279, thr=1.25
# _ligands_connected: Checking GLY-5OL : N-C03, dist=5.872, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-C04, dist=7.177, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-C05, dist=8.298, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-C06, dist=9.647, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-N07, dist=10.684, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-C08, dist=11.965, thr=1.5
# _ligands_connected: Checking GLY-5OL : N-O02, dist=12.098, thr=1.25
# _ligands_connected: Checking GLY-5OL : N-O01, dist=12.403, thr=1.25
# _ligands_connected: Checking GLY-5OL : N-C11, dist=12.979, thr=1.5
# _ligands_connected: Checking GLY-5OL : CA-CA, dist=3.776, thr=1.54
# _ligands_connected: Checking GLY-5OL : CA-N, dist=2.427, thr=1.5
# _ligands_connected: Checking GLY-5OL : CA-C, dist=4.385, thr=1.54
# _ligands_connected: Checking GLY-5OL : CA-O, dist=5.354, thr=1.43
# _ligands_connected: Checking GLY-5OL : CA-C03, dist=4.816, thr=1.54
# _ligands_connected: Checking GLY-5OL : CA-C04, dist=6.195, thr=1.54
# _ligands_connected: Checking GLY-5OL : CA-C05, dist=7.312, thr=1.54
# _ligands_connected: Checking GLY-5OL : CA-C06, dist=8.703, thr=1.54
# _ligands_connected: Checking GLY-5OL : CA-N07, dist=9.714, thr=1.5
# _ligands_connected: Checking GLY-5OL : CA-C08, dist=11.034, thr=1.54
# _ligands_connected: Checking GLY-5OL : CA-O02, dist=11.308, thr=1.43
# _ligands_connected: Checking GLY-5OL : CA-O01, dist=11.434, thr=1.43
# _ligands_connected: Checking GLY-5OL : CA-C11, dist=11.996, thr=1.54
# _ligands_connected: Checking GLY-5OL : C-CA, dist=2.411, thr=1.54
# _ligands_connected: Checking GLY-5OL : C-N, dist=1.331, thr=1.5
# _ligands_connected: FOUND BOND between GLY and 5OL
# save: LIGANDS GLY and 5OL are connected -> union them
# _ligands_connected: Checking GLY-MCM : N-N, dist=5.561, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-CA, dist=6.524, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C2, dist=7.244, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C3, dist=8.359, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C4, dist=10.424, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C5, dist=10.839, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C6, dist=10.151, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C7, dist=8.827, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C8, dist=8.230, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C9, dist=7.079, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-C10, dist=10.912, thr=1.5
# _ligands_connected: Checking GLY-MCM : N-O1, dist=9.248, thr=1.25
# _ligands_connected: Checking GLY-MCM : N-O2, dist=11.273, thr=1.25
# _ligands_connected: Checking GLY-MCM : CA-N, dist=4.285, thr=1.5
# _ligands_connected: Checking GLY-MCM : CA-CA, dist=5.273, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C2, dist=6.148, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C3, dist=7.275, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C4, dist=9.460, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C5, dist=9.793, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C6, dist=9.013, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C7, dist=7.647, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C8, dist=6.948, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C9, dist=5.746, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-C10, dist=9.729, thr=1.54
# _ligands_connected: Checking GLY-MCM : CA-O1, dist=8.283, thr=1.43
# _ligands_connected: Checking GLY-MCM : CA-O2, dist=10.396, thr=1.43
# _ligands_connected: Checking GLY-MCM : C-N, dist=3.234, thr=1.5
# _ligands_connected: Checking GLY-MCM : C-CA, dist=4.357, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C2, dist=5.107, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C3, dist=6.360, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C4, dist=8.563, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C5, dist=9.044, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C6, dist=8.373, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C7, dist=6.949, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C8, dist=6.403, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C9, dist=5.134, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-C10, dist=9.261, thr=1.54
# _ligands_connected: Checking GLY-MCM : C-O1, dist=7.298, thr=1.43
# _ligands_connected: Checking GLY-MCM : C-O2, dist=9.447, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-N, dist=3.495, thr=1.25
# _ligands_connected: Checking GLY-MCM : O-CA, dist=4.447, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C2, dist=4.867, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C3, dist=6.104, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C4, dist=8.135, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C5, dist=8.769, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C6, dist=8.273, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C7, dist=6.900, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C8, dist=6.592, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C9, dist=5.431, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-C10, dist=9.302, thr=1.43
# _ligands_connected: Checking GLY-MCM : O-O1, dist=6.853, thr=1.5
# _ligands_connected: Checking GLY-MCM : O-O2, dist=8.900, thr=1.5
# _ligands_connected: Checking 5OL-MCM : CA-N, dist=2.409, thr=1.5
# _ligands_connected: Checking 5OL-MCM : CA-CA, dist=3.726, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C2, dist=4.424, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C3, dist=5.798, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C4, dist=8.044, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C5, dist=8.618, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C6, dist=8.005, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C7, dist=6.531, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C8, dist=6.068, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C9, dist=4.735, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C10, dist=8.996, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-O1, dist=6.708, thr=1.43
# _ligands_connected: Checking 5OL-MCM : CA-O2, dist=8.904, thr=1.43
# _ligands_connected: Checking 5OL-MCM : N-N, dist=2.679, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-CA, dist=3.999, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C2, dist=4.917, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C3, dist=6.229, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C4, dist=8.543, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C5, dist=8.983, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C6, dist=8.242, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C7, dist=6.766, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C8, dist=6.120, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C9, dist=4.753, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C10, dist=9.098, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-O1, dist=7.255, thr=1.25
# _ligands_connected: Checking 5OL-MCM : N-O2, dist=9.480, thr=1.25
# _ligands_connected: Checking 5OL-MCM : C-N, dist=1.339, thr=1.5
# _ligands_connected: FOUND BOND between 5OL and MCM
# save: LIGANDS 5OL and MCM are connected -> union them
# save: final lig_code=5OLARGGLYMCM
# Duplicate check for: 5efn_5OLARGGLYMCM_chains_B.pdb
# Saved: test/separated_complexes_5efn/5efn_5OLARGGLYMCM_chains_B.pdb
# save: pocket has ligands {'ZN'}, bond_type=
# save: single ligand ZN
# Duplicate check for: 5efn_ZN_chains_A.pdb
#     Protein RMSD = 0.112 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=0.068
#     Ligand RMSD  = 0.068 Å (thr 1.0)
#     -> duplicate detected, skip
# save: pocket has ligands {'EDO'}, bond_type=
# save: single ligand EDO
# Duplicate check for: 5efn_EDO_chains_A.pdb
#     Protein RMSD = 0.112 Å (thr 2.0)
#     Protein RMSD = 0.112 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=26.904
#     Ligand RMSD  = 26.904 Å (thr 1.0)
#     Protein RMSD = 0.112 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=4.753
#     Ligand RMSD  = 4.753 Å (thr 1.0)
#     Protein RMSD = 0.112 Å (thr 2.0)
# Saved: test/separated_complexes_5efn/5efn_EDO_chains_A.pdb
# save: pocket has ligands {'MCM', '5OL'}, bond_type=
# save: multiple ligands ['5OL', 'MCM'], checking connectivity...
# save: minimal distance among ligands in pocket is 1.338
# _ligands_connected: Checking 5OL-MCM : CA-N, dist=2.405, thr=1.5
# _ligands_connected: Checking 5OL-MCM : CA-CA, dist=3.723, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C2, dist=4.429, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C3, dist=5.804, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C4, dist=8.060, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C5, dist=8.626, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C6, dist=8.007, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C7, dist=6.531, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C8, dist=6.062, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C9, dist=4.728, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-C10, dist=8.992, thr=1.54
# _ligands_connected: Checking 5OL-MCM : CA-O1, dist=6.721, thr=1.43
# _ligands_connected: Checking 5OL-MCM : CA-O2, dist=8.935, thr=1.43
# _ligands_connected: Checking 5OL-MCM : N-N, dist=2.721, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-CA, dist=4.021, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C2, dist=4.946, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C3, dist=6.248, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C4, dist=8.565, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C5, dist=8.990, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C6, dist=8.241, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C7, dist=6.770, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C8, dist=6.116, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C9, dist=4.756, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-C10, dist=9.085, thr=1.5
# _ligands_connected: Checking 5OL-MCM : N-O1, dist=7.281, thr=1.25
# _ligands_connected: Checking 5OL-MCM : N-O2, dist=9.516, thr=1.25
# _ligands_connected: Checking 5OL-MCM : C-N, dist=1.338, thr=1.5
# _ligands_connected: FOUND BOND between 5OL and MCM
# save: LIGANDS 5OL and MCM are connected -> union them
# save: final lig_code=5OLMCM
# Duplicate check for: 5efn_5OLMCM_chains_A.pdb
#     Protein RMSD = 0.112 Å (thr 2.0)
#     Protein RMSD = 0.112 Å (thr 2.0)
#     Protein RMSD = 0.112 Å (thr 2.0)
#     Protein RMSD = 0.112 Å (thr 2.0)
# Saved: test/separated_complexes_5efn/5efn_5OLMCM_chains_A.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/1ahy.pdb
# Candidate residues: 4
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['PLP'] -> bond=cov, chains={'A', 'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['MAE'] -> bond=, chains={'A', 'B'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['PLP'] -> bond=cov, chains={'A', 'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['MAE'] -> bond=, chains={'A', 'B'}
# Pockets found: 4
# Total pockets to export: 4
# save: pocket has ligands {'PLP'}, bond_type=cov
# save: single ligand PLP
# Duplicate check for: 1ahy_PLP_chains_A_B_cov.pdb
# Saved: test/separated_complexes_1ahy/1ahy_PLP_chains_A_B_cov.pdb
# save: pocket has ligands {'MAE'}, bond_type=
# save: single ligand MAE
# Duplicate check for: 1ahy_MAE_chains_A_B.pdb
# Saved: test/separated_complexes_1ahy/1ahy_MAE_chains_A_B.pdb
# save: pocket has ligands {'PLP'}, bond_type=cov
# save: single ligand PLP
# Duplicate check for: 1ahy_PLP_chains_A_B_cov_v2.pdb
#     ligand RMSD -> graph mode matched. RMSD=16.383
#     Ligand RMSD  = 16.383 Å (thr 1.0)
# Saved: test/separated_complexes_1ahy/1ahy_PLP_chains_A_B_cov_v2.pdb
# save: pocket has ligands {'MAE'}, bond_type=
# save: single ligand MAE
# Duplicate check for: 1ahy_MAE_chains_A_B_v2.pdb
#     ligand RMSD -> graph mode matched. RMSD=18.979
#     Ligand RMSD  = 18.979 Å (thr 1.0)
# Saved: test/separated_complexes_1ahy/1ahy_MAE_chains_A_B_v2.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/1qjj.pdb
# Candidate residues: 2
#    -> pocket has NO bond_type
# New pocket with residues ['ZN'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['HOA'] -> bond=, chains={'A'}
# Pockets found: 2
# Total pockets to export: 2
# save: pocket has ligands {'ZN'}, bond_type=
# save: single ligand ZN
# Duplicate check for: 1qjj_ZN_chains_A.pdb
# Saved: test/separated_complexes_1qjj/1qjj_ZN_chains_A.pdb
# save: pocket has ligands {'HOA'}, bond_type=
# save: single ligand HOA
# Duplicate check for: 1qjj_HOA_chains_A.pdb
# Saved: test/separated_complexes_1qjj/1qjj_HOA_chains_A.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/2xn7.pdb
# Candidate residues: 5
#    -> pocket has NO bond_type
# New pocket with residues ['T44', 'F6Z'] -> bond=, chains={'A', 'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['EDO'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['CA'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['EDO'] -> bond=, chains={'A', 'B'}
# Pockets found: 4
# Total pockets to export: 4
# save: pocket has ligands {'F6Z', 'T44'}, bond_type=
# save: multiple ligands ['F6Z', 'T44'], checking connectivity...
# save: minimal distance among ligands in pocket is 1.368
# _ligands_connected: Checking T44-F6Z : C1-O1, dist=8.341, thr=1.43
# _ligands_connected: Checking T44-F6Z : C1-C1, dist=8.012, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C2, dist=6.817, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C3, dist=5.809, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C4, dist=5.009, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-O2, dist=8.977, thr=1.43
# _ligands_connected: Checking T44-F6Z : C1-C5, dist=8.469, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C6, dist=8.656, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C7, dist=7.946, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C8, dist=8.490, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C9, dist=9.645, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-O3, dist=10.322, thr=1.43
# _ligands_connected: Checking T44-F6Z : C1-C11, dist=10.285, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C12, dist=9.873, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-O4, dist=10.747, thr=1.43
# _ligands_connected: Checking T44-F6Z : C1-C13, dist=10.438, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C14, dist=11.327, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C15, dist=11.255, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-O5, dist=12.291, thr=1.43
# _ligands_connected: Checking T44-F6Z : C1-C16, dist=10.305, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C17, dist=9.299, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C18, dist=9.342, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C19, dist=7.123, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C20, dist=6.517, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-C21, dist=5.421, thr=1.54
# _ligands_connected: Checking T44-F6Z : C1-O6, dist=4.671, thr=1.43
# _ligands_connected: Checking T44-F6Z : C1-C25, dist=4.181, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-O1, dist=9.032, thr=1.43
# _ligands_connected: Checking T44-F6Z : C2-C1, dist=8.619, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C2, dist=7.442, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C3, dist=6.617, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C4, dist=5.794, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-O2, dist=9.438, thr=1.43
# _ligands_connected: Checking T44-F6Z : C2-C5, dist=8.795, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C6, dist=8.767, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C7, dist=7.986, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C8, dist=8.327, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C9, dist=9.388, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-O3, dist=9.918, thr=1.43
# _ligands_connected: Checking T44-F6Z : C2-C11, dist=10.105, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C12, dist=9.858, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-O4, dist=10.790, thr=1.43
# _ligands_connected: Checking T44-F6Z : C2-C13, dist=10.605, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C14, dist=11.500, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C15, dist=11.543, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-O5, dist=12.573, thr=1.43
# _ligands_connected: Checking T44-F6Z : C2-C16, dist=10.724, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C17, dist=9.746, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C18, dist=9.655, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C19, dist=7.553, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C20, dist=6.870, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-C21, dist=5.933, thr=1.54
# _ligands_connected: Checking T44-F6Z : C2-O6, dist=5.873, thr=1.43
# _ligands_connected: Checking T44-F6Z : C2-C25, dist=5.205, thr=1.54
# _ligands_connected: Checking T44-F6Z : C3-O1, dist=10.397, thr=1.43
# _ligands_connected: Checking T44-F6Z : C3-C1, dist=10.001, thr=1.54
# ...
# _ligands_connected: Checking UNK-UNK : CB-C, dist=7.375, thr=1.54
# _ligands_connected: Checking UNK-UNK : CB-O, dist=8.574, thr=1.43
# _ligands_connected: Checking UNK-UNK : CB-CB, dist=7.885, thr=1.54
# _ligands_connected: Checking FTY-UNK : N-N, dist=3.283, thr=1.5
# _ligands_connected: Checking FTY-UNK : N-CA, dist=4.728, thr=1.5
# _ligands_connected: Checking FTY-UNK : N-C, dist=5.421, thr=1.5
# _ligands_connected: Checking FTY-UNK : N-O, dist=6.652, thr=1.25
# _ligands_connected: Checking FTY-UNK : N-CB, dist=5.537, thr=1.5
# _ligands_connected: Checking FTY-UNK : CA-N, dist=2.381, thr=1.5
# _ligands_connected: Checking FTY-UNK : CA-CA, dist=3.755, thr=1.54
# _ligands_connected: Checking FTY-UNK : CA-C, dist=4.494, thr=1.54
# _ligands_connected: Checking FTY-UNK : CA-O, dist=5.665, thr=1.43
# _ligands_connected: Checking FTY-UNK : CA-CB, dist=4.327, thr=1.54
# _ligands_connected: Checking FTY-UNK : C-N, dist=1.334, thr=1.5
# _ligands_connected: FOUND BOND between FTY and UNK
# save: LIGANDS FTY and UNK are connected -> union them
# save: final lig_code=FTYUNKUNKUNK
# Duplicate check for: 4gs0_FTYUNKUNKUNK_chains_B.pdb
# Saved: test/separated_complexes_4gs0/4gs0_FTYUNKUNKUNK_chains_B.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/9fxq.pdb
# Candidate residues: 2
#    -> pocket has NO bond_type
# New pocket with residues ['CPS'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['FAD'] -> bond=, chains={'A'}
# Pockets found: 2
# Total pockets to export: 2
# save: pocket has ligands {'CPS'}, bond_type=
# save: single ligand CPS
# Duplicate check for: 9fxq_CPS_chains_A.pdb
# Saved: test/separated_complexes_9fxq/9fxq_CPS_chains_A.pdb
# save: pocket has ligands {'FAD'}, bond_type=
# save: single ligand FAD
# Duplicate check for: 9fxq_FAD_chains_A.pdb
# Saved: test/separated_complexes_9fxq/9fxq_FAD_chains_A.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/3qfy.pdb
# Candidate residues: 10
#    -> pocket has NO bond_type
# New pocket with residues ['BGC'] -> bond=, chains={'A', 'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['IFM'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['EPE'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['BGC'] -> bond=, chains={'A', 'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['IFM'] -> bond=, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'B'}
# Pockets found: 10
# Overabundant filter (min 1, limit 3, protect 3.0 Å): removed 3 pockets
# Total pockets to export: 7
# save: pocket has ligands {'BGC'}, bond_type=
# save: single ligand BGC
# Duplicate check for: 3qfy_BGC_chains_A_B.pdb
# Saved: test/separated_complexes_3qfy/3qfy_BGC_chains_A_B.pdb
# save: pocket has ligands {'SO4'}, bond_type=
# save: single ligand SO4
# Duplicate check for: 3qfy_SO4_chains_A.pdb
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_3qfy/3qfy_SO4_chains_A.pdb
# save: pocket has ligands {'IFM'}, bond_type=
# save: single ligand IFM
# Duplicate check for: 3qfy_IFM_chains_A.pdb
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_3qfy/3qfy_IFM_chains_A.pdb
# save: pocket has ligands {'EPE'}, bond_type=
# save: single ligand EPE
# Duplicate check for: 3qfy_EPE_chains_A.pdb
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_3qfy/3qfy_EPE_chains_A.pdb
# save: pocket has ligands {'BGC'}, bond_type=
# save: single ligand BGC
# Duplicate check for: 3qfy_BGC_chains_A_B_v2.pdb
#     ligand RMSD -> graph mode matched. RMSD=18.615
#     Ligand RMSD  = 18.615 Å (thr 1.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_3qfy/3qfy_BGC_chains_A_B_v2.pdb
# save: pocket has ligands {'SO4'}, bond_type=
# save: single ligand SO4
# Duplicate check for: 3qfy_SO4_chains_B.pdb
#     Protein RMSD = 0.136 Å (thr 2.0)
#     Protein RMSD = 0.136 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=1.244
#     Ligand RMSD  = 1.244 Å (thr 1.0)
#     Protein RMSD = 0.136 Å (thr 2.0)
#     Protein RMSD = 0.136 Å (thr 2.0)
#     Protein RMSD = 0.136 Å (thr 2.0)
# Saved: test/separated_complexes_3qfy/3qfy_SO4_chains_B.pdb
# save: pocket has ligands {'IFM'}, bond_type=
# save: single ligand IFM
# Duplicate check for: 3qfy_IFM_chains_B.pdb
#     Protein RMSD = 0.136 Å (thr 2.0)
#     Protein RMSD = 0.136 Å (thr 2.0)
#     Protein RMSD = 0.136 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=0.097
#     Ligand RMSD  = 0.097 Å (thr 1.0)
#     -> duplicate detected, skip
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/2ccc.pdb
# Candidate residues: 6
#    -> pocket has NO bond_type
# New pocket with residues ['MG'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['NA'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['CL'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['MG'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['LFN'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['SO4'] -> bond=, chains={'A'}
# Pockets found: 6
# Total pockets to export: 6
# save: pocket has ligands {'MG'}, bond_type=
# save: single ligand MG
# Duplicate check for: 2ccc_MG_chains_A.pdb
# Saved: test/separated_complexes_2ccc/2ccc_MG_chains_A.pdb
# save: pocket has ligands {'NA'}, bond_type=
# save: single ligand NA
# Duplicate check for: 2ccc_NA_chains_A.pdb
# Saved: test/separated_complexes_2ccc/2ccc_NA_chains_A.pdb
# save: pocket has ligands {'CL'}, bond_type=
# save: single ligand CL
# Duplicate check for: 2ccc_CL_chains_A.pdb
# Saved: test/separated_complexes_2ccc/2ccc_CL_chains_A.pdb
# save: pocket has ligands {'MG'}, bond_type=
# save: single ligand MG
# Duplicate check for: 2ccc_MG_chains_A_v2.pdb
#     ligand RMSD -> graph mode matched. RMSD=19.415
#     Ligand RMSD  = 19.415 Å (thr 1.0)
# Saved: test/separated_complexes_2ccc/2ccc_MG_chains_A_v2.pdb
# save: pocket has ligands {'LFN'}, bond_type=
# save: single ligand LFN
# Duplicate check for: 2ccc_LFN_chains_A.pdb
# Saved: test/separated_complexes_2ccc/2ccc_LFN_chains_A.pdb
# save: pocket has ligands {'SO4'}, bond_type=
# save: single ligand SO4
# Duplicate check for: 2ccc_SO4_chains_A.pdb
# Saved: test/separated_complexes_2ccc/2ccc_SO4_chains_A.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/5oxm.pdb
# Candidate residues: 22
#    -> pocket has NO bond_type
# New pocket with residues ['PO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['PO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['PO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['PO4'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78M'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78M'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['78N'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['ASP', 'GLU'] -> bond=, chains={'A'}
# Pockets found: 21
# Overabundant filter (min 1, limit 3, protect 3.0 Å): removed 17 pockets
# Total pockets to export: 4
# save: pocket has ligands {'PO4'}, bond_type=
# save: single ligand PO4
# Duplicate check for: 5oxm_PO4_chains_A.pdb
# Saved: test/separated_complexes_5oxm/5oxm_PO4_chains_A.pdb
# save: pocket has ligands {'78M'}, bond_type=
# save: single ligand 78M
# Duplicate check for: 5oxm_78M_chains_A.pdb
# Saved: test/separated_complexes_5oxm/5oxm_78M_chains_A.pdb
# save: pocket has ligands {'78M'}, bond_type=
# save: single ligand 78M
# Duplicate check for: 5oxm_78M_chains_A_v2.pdb
#     ligand RMSD -> graph mode matched. RMSD=28.206
#     Ligand RMSD  = 28.206 Å (thr 1.0)
# Saved: test/separated_complexes_5oxm/5oxm_78M_chains_A_v2.pdb
# save: pocket has ligands {'GLU', 'ASP'}, bond_type=
# save: multiple ligands ['ASP', 'GLU'], checking connectivity...
# save: minimal distance among ligands in pocket is 1.327
# _ligands_connected: Checking ASP-GLU : N-N, dist=3.229, thr=1.5
# _ligands_connected: Checking ASP-GLU : N-CA, dist=4.554, thr=1.5
# _ligands_connected: Checking ASP-GLU : N-C, dist=5.451, thr=1.5
# _ligands_connected: Checking ASP-GLU : N-O, dist=6.473, thr=1.25
# _ligands_connected: Checking ASP-GLU : N-CB, dist=5.463, thr=1.5
# _ligands_connected: Checking ASP-GLU : N-CG, dist=5.678, thr=1.5
# _ligands_connected: Checking ASP-GLU : N-CD, dist=6.977, thr=1.5
# _ligands_connected: Checking ASP-GLU : N-OE1, dist=7.798, thr=1.25
# _ligands_connected: Checking ASP-GLU : N-OE2, dist=7.375, thr=1.25
# _ligands_connected: Checking ASP-GLU : N-OXT, dist=5.467, thr=1.25
# _ligands_connected: Checking ASP-GLU : CA-N, dist=2.402, thr=1.5
# _ligands_connected: Checking ASP-GLU : CA-CA, dist=3.782, thr=1.54
# _ligands_connected: Checking ASP-GLU : CA-C, dist=4.386, thr=1.54
# _ligands_connected: Checking ASP-GLU : CA-O, dist=5.475, thr=1.43
# _ligands_connected: Checking ASP-GLU : CA-CB, dist=4.812, thr=1.54
# _ligands_connected: Checking ASP-GLU : CA-CG, dist=4.903, thr=1.54
# _ligands_connected: Checking ASP-GLU : CA-CD, dist=6.318, thr=1.54
# _ligands_connected: Checking ASP-GLU : CA-OE1, dist=7.185, thr=1.43
# _ligands_connected: Checking ASP-GLU : CA-OE2, dist=6.754, thr=1.43
# _ligands_connected: Checking ASP-GLU : CA-OXT, dist=4.187, thr=1.43
# _ligands_connected: Checking ASP-GLU : C-N, dist=1.327, thr=1.5
# _ligands_connected: FOUND BOND between ASP and GLU
# save: LIGANDS ASP and GLU are connected -> union them
# save: final lig_code=ASPGLU
# Duplicate check for: 5oxm_ASPGLU_chains_A.pdb
# Saved: test/separated_complexes_5oxm/5oxm_ASPGLU_chains_A.pdb
# Done
# Start: /home/nikolenko/work/Projects/LPCE/lpce/tests/test_data/6f7w.pdb
# Candidate residues: 24
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['SNM'] -> bond=cov, chains={'A', 'B'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'A'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'A'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['QQ7'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'A', 'C'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'A'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'A'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['SNM'] -> bond=cov, chains={'C', 'B'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'B'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'B'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['QQ7'] -> bond=, chains={'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'A', 'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'B'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['SNM'] -> bond=cov, chains={'A', 'C'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'C'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'C'}
#    -> recognized as COV bond
#    -> pocket has COV bond
# New pocket with residues ['MLY'] -> bond=cov, chains={'C'}
#    -> pocket has NO bond_type
# New pocket with residues ['QQ7'] -> bond=, chains={'C'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'C', 'B'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'C'}
#    -> pocket has NO bond_type
# New pocket with residues ['GOL'] -> bond=, chains={'A', 'C'}
# Pockets found: 23
# Overabundant filter (min 3, limit 5, protect 3.0 Å): removed 16 pockets
# Total pockets to export: 7
# save: pocket has ligands {'SNM'}, bond_type=cov
# save: single ligand SNM
# Duplicate check for: 6f7w_SNM_chains_A_B_cov.pdb
# Saved: test/separated_complexes_6f7w/6f7w_SNM_chains_A_B_cov.pdb
# save: pocket has ligands {'QQ7'}, bond_type=
# save: single ligand QQ7
# Duplicate check for: 6f7w_QQ7_chains_A.pdb
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_6f7w/6f7w_QQ7_chains_A.pdb
# save: pocket has ligands {'SNM'}, bond_type=cov
# save: single ligand SNM
# Duplicate check for: 6f7w_SNM_chains_B_C_cov.pdb
#     Protein RMSD = 0.074 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=1.693
#     Ligand RMSD  = 1.693 Å (thr 1.0)
#     Protein RMSD = 0.059 Å (thr 2.0)
# Saved: test/separated_complexes_6f7w/6f7w_SNM_chains_B_C_cov.pdb
# save: pocket has ligands {'QQ7'}, bond_type=
# save: single ligand QQ7
# Duplicate check for: 6f7w_QQ7_chains_B.pdb
#     Protein RMSD = 0.059 Å (thr 2.0)
#     Protein RMSD = 0.059 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=4.647
#     Ligand RMSD  = 4.647 Å (thr 1.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_6f7w/6f7w_QQ7_chains_B.pdb
# save: pocket has ligands {'SNM'}, bond_type=cov
# save: single ligand SNM
# Duplicate check for: 6f7w_SNM_chains_A_C_cov.pdb
#     Protein RMSD = 8.658 Å (thr 2.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
#     Protein RMSD = 8.636 Å (thr 2.0)
#     Protein RMSD = 0.059 Å (thr 2.0)
# Saved: test/separated_complexes_6f7w/6f7w_SNM_chains_A_C_cov.pdb
# save: pocket has ligands {'QQ7'}, bond_type=
# save: single ligand QQ7
# Duplicate check for: 6f7w_QQ7_chains_C.pdb
#     Protein RMSD = 0.069 Å (thr 2.0)
#     Protein RMSD = 0.066 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=2.691
#     Ligand RMSD  = 2.691 Å (thr 1.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
#     Protein RMSD = 0.059 Å (thr 2.0)
#     ligand RMSD -> graph mode matched. RMSD=4.702
#     Ligand RMSD  = 4.702 Å (thr 1.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_6f7w/6f7w_QQ7_chains_C.pdb
# save: pocket has ligands {'GOL'}, bond_type=
# save: single ligand GOL
# Duplicate check for: 6f7w_GOL_chains_A_C.pdb
#     Protein RMSD = 8.658 Å (thr 2.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
#     Protein RMSD = 8.636 Å (thr 2.0)
#     Protein RMSD = 0.059 Å (thr 2.0)
#     Protein RMSD = 0.000 Å (thr 2.0)
# Saved: test/separated_complexes_6f7w/6f7w_GOL_chains_A_C.pdb
# Done

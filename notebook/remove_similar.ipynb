# %%
import subprocess
import sys
from pathlib import Path
from loguru import logger
from tqdm import tqdm
import tempfile

logger.remove()
logger.add(sys.stdout, format="{message}", level="INFO")

def run_foldseek(input_dir, tmscore_threshold=0.5, fident_threshold=0.9, n_jobs=224):
    """
    Runs Foldseek with specified parameters.

    :param input_dir: Directory containing input PDB files.
    :param tmscore_threshold: TM-score threshold for Foldseek.
    :param fident_threshold: Identity threshold for grouping results.
    :param n_jobs: Number of threads for Foldseek.
    """
    identical_pairs = {}

    with tempfile.TemporaryDirectory() as tmp_dir:
        output_dir = Path(tmp_dir)
        db_path = output_dir / "foldseek_db"
        aln_output = output_dir / "alignment_results.m8"
        foldseek_log = "foldseek_output.log"
        foldseek_bin = "/home/nikolenko/work/soft/foldseek/bin/foldseek"
        prostt5_path = "/home/nikolenko/work/soft/prostt5_model"

        logger.info("Starting run_foldseek")
        logger.info(f"Input directory: {input_dir}")
        logger.info(f"Foldseek binary: {foldseek_bin}")

        try:
            # Handle the 'createdb' step
            with open(foldseek_log, "w") as log_file:
                logger.info("Creating Foldseek database...")
                createdb_command = [
                    foldseek_bin,
                    "createdb",
                    str(input_dir),
                    str(db_path),
                    "--threads", str(n_jobs)
                ]
                process = subprocess.Popen(
                    createdb_command,
                    stdout=subprocess.PIPE,
                    stderr=subprocess.STDOUT,
                    universal_newlines=True
                )
                logger.info("createdb process started")

                # Initialize progress bar for 'createdb'
                total_equals_createdb = 65  # Assuming progress bar has 65 '=' characters
                pbar_createdb = tqdm(total=total_equals_createdb, desc="Creating Database", unit="chars")

                for line in process.stdout:
                    log_file.write(line)
                    if line.startswith('[') and ']' in line:
                        # Extract the progress bar part
                        progress_bar = line[line.find('['):line.find(']')+1]
                        num_equals = progress_bar.count('=')
                        pbar_createdb.n = num_equals
                        pbar_createdb.refresh()
                process.wait()
                pbar_createdb.close()
                if process.returncode != 0:
                    logger.error("Foldseek exited with an error during 'createdb'")
                    raise RuntimeError("Foldseek 'createdb' exited with an error.")
                logger.info(f"Database created at {db_path}")

            # Handle the 'easy-search' step
            with open(foldseek_log, "a") as log_file:
                logger.info("Starting easy-search...")
                command = [
                    foldseek_bin,
                    "easy-search",
                    str(db_path),
                    str(db_path),
                    str(aln_output),
                    str(output_dir),
                    "--format-output", "query,target,fident,evalue",
                    "--max-seqs", "10000",
                    "--alignment-type", "2",
                    "--tmscore-threshold", str(tmscore_threshold),
                    "--threads", str(n_jobs),
                    "--prostt5-model", prostt5_path 
                ]

                process = subprocess.Popen(
                    command,
                    stdout=subprocess.PIPE,
                    stderr=subprocess.STDOUT,
                    universal_newlines=True
                )

                logger.info("easy-search process started")

                # Initialize progress bar for 'easy-search'
                total_equals_easysearch = 5 * 65
                pbar_easysearch = tqdm(total=total_equals_easysearch, desc="Foldseek Progress", unit="chars")

                # Read the output character by character
                while True:
                    char = process.stdout.read(1)
                    if not char:
                        break
                    log_file.write(char)
                    if char == '=':
                        pbar_easysearch.update(1)

                process.wait()
                pbar_easysearch.close()

                if process.returncode != 0:
                    logger.error("Foldseek exited with an error in easy-search")
                    raise RuntimeError("Foldseek exited with an error.")

        except subprocess.CalledProcessError as e:
            logger.error(f"Foldseek failed to create the database: {e}")
            sys.exit(1)

        # Reading and processing Foldseek results
        logger.info("Reading Foldseek alignment results")
        with open(aln_output, 'r') as f:
            for line in f:
                query, target, fident, evalue = line.strip().split()[:4]
                fident = float(fident)
                if fident >= fident_threshold:
                    if query not in identical_pairs:
                        identical_pairs[query] = {query}
                    identical_pairs[query].add(target)

        logger.info("Grouping identical structures")
        groups = []
        visited = set()
        for key, group in identical_pairs.items():
            if key not in visited:
                groups.append(group)
                visited.update(group)

        logger.info(f"run_foldseek completed, found {len(groups)} groups of identical structures")
        return groups


def find_identical_in_directory_foldseek(input_dir, tmscore_threshold=0.5, fident_threshold=0.9, n_jobs=224):
    """
    High-level function to find identical structures using Foldseek.

    :param input_dir: Directory with input PDB files.
    :param tmscore_threshold: TM-score threshold for Foldseek.
    :param fident_threshold: Identity threshold for grouping results.
    :param n_jobs: Number of threads for Foldseek.
    :return: List of groups of identical structures.
    """
    input_dir = Path(input_dir)

    logger.info(f"Searching for identical structures in {input_dir} with Foldseek")
    logger.info(f"tmscore_threshold = {tmscore_threshold}, fident_threshold = {fident_threshold}, n_jobs = {n_jobs}")

    groups = run_foldseek(input_dir, tmscore_threshold, fident_threshold, n_jobs)

    logger.info(f"Search completed. Found {len(groups)} groups of identical structures.")
    return groups

# %%
#identical_groups = find_identical_in_directory_foldseek("../lpce/tests/separated", tmscore_threshold=0.8, fident_threshold=0.8, n_jobs=112)
identical_groups = find_identical_in_directory_foldseek("/mnt/ligandpro/db/LPCE/separated", tmscore_threshold=0.8, fident_threshold=0.8, n_jobs=112)
# Out:
# Searching for identical structures in /mnt/ligandpro/db/LPCE/separated with Foldseek
# tmscore_threshold = 0.8, fident_threshold = 0.8, n_jobs = 112
# Starting run_foldseek
# Input directory: /mnt/ligandpro/db/LPCE/separated
# Foldseek binary: /home/nikolenko/work/soft/foldseek/bin/foldseek
# Creating Foldseek database...
# createdb process started
# Creating Database: 100%|██████████| 65/65 [07:38<00:00,  7.05s/chars]
# Database created at /tmp/tmp878__7cp/foldseek_db
# Starting easy-search...
# easy-search process started
# Foldseek Progress: 100%|██████████| 325/325 [16:24<00:00,  3.03s/chars]
# Reading Foldseek alignment results
# Grouping identical structures
# run_foldseek completed, found 14883 groups of identical structures
# Search completed. Found 14883 groups of identical structures.

# %%
identical_groups
# Out:
# [{'1a0f_bioml_1_GTS_chains_A_B_processed_A',
#   '1a0f_bioml_1_GTS_chains_A_B_processed_B'},
#  {'1a3o_bioml_1_HEM_chains_A_processed',
#   '1abw_bioml_1_LEU_MET_chains_A_processed',
#   '1b86_bioml_1_HEM_OXY_chains_A_processed',
#   '1bbb_bioml_1_CMO_HEM_chains_A_processed'},
#  {'1ahf_bioml_1_PLP_chains_A_B_processed_A',
#   '1ahf_bioml_1_PLP_chains_A_B_processed_B',
#   '1ahy_bioml_1_MAE_PLP_chains_A_B_processed_A',
#   '1ahy_bioml_1_MAE_PLP_chains_A_B_processed_B',
#   '1amr_bioml_1_MAE_chains_A_processed',
#   '1arg_bioml_1_PPD_chains_A_B_processed_A',
#   '1arg_bioml_1_PPD_chains_A_B_processed_B',
#   '1ars_bioml_1_PLP_chains_A_processed',
#   '1art_bioml_1_0A0_PLP_chains_A_processed'},
#  {'1a25_bioml_1_PSE_chains_B_processed'},
#  {'1ab8_bioml_1_FOK_chains_A_B_processed_A',
#   '1ab8_bioml_1_FOK_chains_A_B_processed_B'},
#  {'1a65_bioml_1_PYE_chains_A_processed'},
#  {'1ay5_bioml_1_MAE_PLP_chains_A_B_processed_A',
#   '1ay5_bioml_1_MAE_PLP_chains_A_B_processed_B',
#   '1ay8_bioml_1_PLP_chains_A_B_processed_A',
#   '1ay8_bioml_1_PLP_chains_A_B_processed_B'},
#  {'1bfd_bioml_1_TPP_chains_A_processed'},
#  {'1agr_bioml_1_ALF_GDP_MG_chains_A_processed',
#   '1as3_bioml_1_GDP_chains_A_processed',
#   '1bof_bioml_1_GDP_MG_chains_A_processed'},
#  {'1a8e_bioml_1_CO3_FE_chains_A_processed'},
#  {'1amu_bioml_1_AMP_MG_chains_A_processed',
#   '1amu_bioml_2_AMP_MG_chains_B_processed'},
#  {'1a71_bioml_1_NAD_chains_A_B_processed_A',
#   '1a71_bioml_1_NAD_chains_A_B_processed_B'},
#  {'1ay0_bioml_1_CA_TPP_chains_A_processed'},
#  {'1ay2_bioml_1_HTO_chains_A_processed'},
#  {'1afw_bioml_1_MRD_chains_A_B_processed_A',
#   '1afw_bioml_1_MRD_chains_A_B_processed_B'},
#  {'1b8v_bioml_1_NAD_chains_A_processed'},
#  {'1bd4_bioml_1_URA_chains_D_processed'},
#  {'1shz_bioml_1_GDP_chains_A_processed'},
#  {'1b7v_bioml_1_HEC_chains_A_processed'},
#  {'1a3o_bioml_1_HEM_chains_B_processed',
#   '1bbb_bioml_1_CMO_HEM_chains_B_processed'},
#  {'1a8r_bioml_1_GTP_chains_A_B_processed_A',
#   '1a8r_bioml_1_GTP_chains_A_B_processed_B'},
#  {'12gs_bioml_1_0HH_chains_A_B_processed_A',
#   '12gs_bioml_1_0HH_chains_A_B_processed_B',
#   '17gs_bioml_1_GTX_chains_A_B_processed_A',
#   '17gs_bioml_1_GTX_chains_A_B_processed_B',
#   '19gs_bioml_1_BSP_GSH_chains_A_processed',
#   '1aqw_bioml_1_GSH_chains_A_B_processed_A',
#   '1aqw_bioml_1_GSH_chains_A_B_processed_B'},
#  {'1a2q_bioml_1_ACN_chains_A_processed'},
#  {'1axr_bioml_1_PLP_chains_A_processed',
#   '1b4d_bioml_1_CRA_chains_A_processed'},
#  {'1ar5_bioml_1_FE_chains_A_processed',
#   '1bs3_bioml_1_F_FE_chains_A_processed'},
#  {'1bg3_bioml_1_G6P_chains_A_processed',
#   '1bg3_bioml_2_G6P_chains_B_processed'},
#  {'1a47_bioml_1_ADH_chains_A_processed'},
#  {'1brd_bioml_1_RET_chains_A_processed'},
#  {'1bmf_bioml_1_ADP_chains_C_D_processed_C'},
#  {'102m_bioml_1_HEM_chains_A_processed',
#   '104m_bioml_1_HEM_NBN_chains_A_processed',
#   '109m_bioml_1_ENC_HEM_chains_A_processed',
#   '110m_bioml_1_HEM_MNC_chains_A_processed',
#   '112m_bioml_1_HEM_NPN_chains_A_processed',
#   '1a6m_bioml_1_HEM_OXY_chains_A_processed',
#   '1ajh_bioml_1_CMO_HEM_chains_A_processed',
#   '1bje_bioml_1_AZI_HEM_chains_A_processed'},
#  {'1bi9_bioml_1_NAD_chains_A_processed',
#   '1bi9_bioml_1_NAD_chains_C_processed',
#   '1bi9_bioml_1_NAD_chains_D_processed'},
#  {'1bru_bioml_1_1NB_chains_P_processed'},
#  {'1aj8_bioml_1_COA_chains_A_B_processed_A',
#   '1aj8_bioml_1_COA_chains_A_B_processed_B'},
#  {'1bo8_bioml_1_U_chains_A_processed'},
#  {'1axw_bioml_1_UMP_chains_A_B_processed_A',
#   '1axw_bioml_1_UMP_chains_A_B_processed_B'},
#  {'1bph_bioml_1_DCE_chains_B_processed'},
#  {'1bq6_bioml_1_COA_chains_A_processed'},
#  {'1aer_bioml_1_AMP_chains_B_processed'},
#  {'1b5o_bioml_1_PLP_chains_A_B_processed_A',
#   '1b5o_bioml_1_PLP_chains_A_B_processed_B'},
#  {'1axz_bioml_1_GAL_GLA_chains_A_processed'},
#  {'1aeb_bioml_1_3MT_HEM_chains_A_processed',
#   '1aed_bioml_1_DTI_HEM_chains_A_processed',
#   '1aen_bioml_1_25T_HEM_chains_A_processed',
#   '1aes_bioml_1_HEM_chains_A_processed',
#   '1aet_bioml_1_1MZ_HEM_chains_A_processed',
#   '1bes_bioml_1_CL_HEM_chains_A_processed'},
#  {'1bbp_bioml_1_BLV_chains_A_C_processed_A',
#   '1bbp_bioml_1_BLV_chains_A_C_processed_C'},
#  {'1aon_bioml_1_ADP_MG_chains_A_processed'},
#  {'1a4f_bioml_1_HEM_OXY_chains_B_processed'},
#  {'148l_bioml_1_MUB_chains_E_S_processed_E',
#   '184l_bioml_1_HED_chains_A_processed'},
#  {'1atj_bioml_1_HEM_chains_A_processed'},
#  {'1bhn_bioml_1_35G_GDP_chains_A_B_processed_A',
#   '1bhn_bioml_1_35G_GDP_chains_A_B_processed_B'},
#  {'1atp_bioml_1_ATP_MN_chains_E_processed'},
#  {'1bcf_bioml_1_HEM_chains_A_B_processed_A',
#   '1bcf_bioml_1_HEM_chains_A_B_processed_B'},
#  {'1a5b_bioml_1_PLP_chains_B_processed',
#   '1a5s_bioml_1_PLP_SER_chains_B_processed',
#   '1beu_bioml_1_PLS_chains_B_processed'},
#  {'1a2s_bioml_1_HEC_chains_A_processed'},
#  {'1b7z_bioml_1_FE_chains_A_processed'},
#  {'1ai8_bioml_1_T42_chains_H_processed',
#   '1awh_bioml_1_GR3_chains_B_processed',
#   '1bcu_bioml_1_PRL_chains_H_processed'},
#  {'1agn_bioml_1_NAD_chains_A_B_processed_A',
#   '1agn_bioml_1_NAD_chains_A_B_processed_B'},
#  {'1ads_bioml_1_NAP_chains_A_processed'},
#  {'1akr_bioml_1_FMN_chains_A_processed'},
#  {'1br6_bioml_1_PT1_chains_A_processed'},
#  {'1a27_bioml_1_NAP_chains_A_processed'},
#  {'1bs1_bioml_1_ADP_DAA_MG_chains_A_processed'},
#  {'1a9r_bioml_1_HPA_chains_A_processed',
#   '1a9t_bioml_1_HPA_R1P_chains_A_processed'},
#  {'1bkj_bioml_1_FMN_chains_A_B_processed_A',
#   '1bkj_bioml_1_FMN_chains_A_B_processed_B'},
#  {'1a7a_bioml_1_NAD_chains_A_B_processed_A',
#   '1a7a_bioml_1_NAD_chains_A_B_processed_B'},
#  {'1ag9_bioml_1_FMN_chains_A_processed'},
#  {'1bo4_bioml_1_COA_chains_A_processed'},
#  {'1bky_bioml_1_SAH_chains_A_processed'},
#  {'1a28_bioml_1_STR_chains_A_processed'},
#  {'1a05_bioml_1_IPM_MG_chains_A_B_processed_A',
#   '1a05_bioml_1_IPM_MG_chains_A_B_processed_B'},
#  {'1b3n_bioml_1_CER_chains_A_processed'},
#  {'1ahv_bioml_1_FAD_chains_A_processed',
#   '1ahz_bioml_1_CL_FAD_chains_A_processed'},
#  {'1aoq_bioml_1_HEM_chains_A_processed'},
#  {'1atn_bioml_1_ATP_chains_A_processed'},
#  {'1bg9_bioml_1_AF1_chains_A_processed'},
#  {'1brx_bioml_1_RET_chains_A_processed'},
#  {'1b0u_bioml_1_ATP_chains_A_processed'},
#  {'1b59_bioml_1_OVA_chains_A_processed',
#   '1b6a_bioml_1_TN4_chains_A_processed'},
#  {'1b3a_bioml_1_AOP_chains_A_processed'},
#  {'1bg2_bioml_1_ADP_MG_chains_A_processed'},
#  {'1a4f_bioml_1_HEM_OXY_chains_A_processed'},
#  {'1bt5_bioml_1_IM2_chains_A_processed'},
#  {'1akk_bioml_1_HEC_chains_A_processed'},
#  {'1b48_bioml_1_HAG_chains_A_B_processed_A',
#   '1b48_bioml_1_HAG_chains_A_B_processed_B'},
#  {'1al8_bioml_1_DHP_FMN_chains_A_processed'},
#  {'1apx_bioml_1_HEM_chains_A_processed'},
#  {'1ae4_bioml_1_NAP_chains_A_processed'},
#  {'1aec_bioml_1_E64_chains_A_processed'},
#  {'1bcc_bioml_1_HEM_chains_C_processed'},
#  {'1biw_bioml_1_S80_chains_B_processed'},
#  {'1biq_bioml_1_FE_chains_A_processed'},
#  {'1au8_bioml_1_0H8_chains_A_processed'},
#  {'1b2l_bioml_1_CYH_chains_A_processed'},
#  {'1af7_bioml_1_SAH_chains_A_processed'},
#  {'1aqb_bioml_1_RTL_chains_A_processed'},
#  {'1a4r_bioml_1_GDP_MG_chains_A_processed'},
#  {'1bmf_bioml_1_ADP_chains_C_D_processed_D'},
#  {'1a8p_bioml_1_FAD_chains_A_processed'},
#  {'1a9w_bioml_1_CMO_HEM_chains_E_processed'},
#  {'1bgp_bioml_1_HEM_chains_A_processed'},
#  {'1bls_bioml_1_IPP_chains_A_processed'},
#  {'1at1_bioml_1_PCT_chains_A_processed'},
#  {'1b6p_bioml_1_PI7_chains_A_B_processed_A',
#   '1b6p_bioml_1_PI7_chains_A_B_processed_B'},
#  {'1a6e_bioml_1_ADP_AF3_MG_chains_A_processed'},
#  {'1bqy_bioml_1_0GJ_chains_A_processed'},
#  {'1asp_bioml_1_PEO_chains_A_processed'},
#  {'1af0_bioml_1_0Z9_ZN_chains_A_processed'},
#  {'1a99_bioml_1_PUT_chains_A_processed'},
#  {'1b0l_bioml_1_CO3_FE_chains_A_processed'},
#  {'1ank_bioml_1_AMP_chains_A_processed'},
#  {'1a59_bioml_1_COA_chains_A_processed'},
#  {'1aj2_bioml_1_2PH_chains_A_processed'},
#  {'1b5m_bioml_1_HEM_chains_A_processed'},
#  {'1be6_bioml_1_CCN_chains_A_processed'},
#  {'1aqi_bioml_1_SAH_chains_A_processed'},
#  {'13pk_bioml_1_ADP_MG_chains_A_processed'},
#  {'1arv_bioml_1_CYN_HEM_chains_A_processed',
#   '1ary_bioml_1_HEM_chains_A_processed'},
#  {'1b2r_bioml_1_FAD_chains_A_processed'},
#  {'1a6e_bioml_1_ADP_AF3_MG_chains_B_processed'},
#  {'1a5v_bioml_1_Y3_chains_A_processed'},
#  {'1bdb_bioml_1_NAD_chains_A_processed'},
#  {'19hc_bioml_1_HEM_chains_A_processed'},
#  {'12as_bioml_1_AMP_ASN_chains_A_processed'},
#  {'155c_bioml_1_HEM_chains_A_processed'},
#  {'1bgn_bioml_1_FAD_chains_A_processed'},
#  {'1bh5_bioml_1_GTX_chains_A_B_processed_A',
#   '1bh5_bioml_1_GTX_chains_A_B_processed_B'},
#  {'1amo_bioml_1_FAD_FMN_chains_A_processed'},
#  {'1ash_bioml_1_HEM_OXY_chains_A_processed'},
#  {'1aw3_bioml_1_HEM_chains_A_processed'},
#  {'1bbh_bioml_1_HEC_chains_A_processed'},
#  {'1a3g_bioml_1_PLP_chains_A_processed'},
#  {'1b2j_bioml_1_FE_chains_A_processed'},
#  {'1bcc_bioml_1_HEM_chains_D_processed'},
#  {'1bq9_bioml_1_FE_chains_A_processed'},
#  {'1am1_bioml_1_ADP_chains_A_processed'},
#  {'1b5j_bioml_1_U1_chains_A_processed'},
#  {'1afb_bioml_1_NGA_chains_1_processed'},
#  {'1b4v_bioml_1_FAD_chains_A_processed'},
#  {'1biy_bioml_1_CO3_FE_chains_A_processed'},
#  {'1aq2_bioml_1_ATP_MN_chains_A_processed'},
#  {'1a0i_bioml_1_ATP_chains_A_processed'},
#  {'1b2y_bioml_1_AC1_chains_A_processed_A'},
#  {'1am6_bioml_1_HAE_ZN_chains_A_processed'},
#  {'1b85_bioml_1_HEM_chains_A_processed'},
#  {'1ats_bioml_1_ADP_MG_chains_A_processed'}]

# %%
import json
identical_groups_json_compatible = [list(group) for group in identical_groups]
with open("../data/identical_groups.json", "w") as f:
    json.dump(identical_groups_json_compatible, f)

# %%
import os
import json
from collections import defaultdict
from loguru import logger

def extract_het_and_chain_identifiers(filename):
    try:
        start_het = filename.index('bioml_1_') + len('bioml_1_')
        end_het = filename.index('_chains_')
        het_identifier = filename[start_het:end_het]
        
        start_chain = end_het + len('_chains_')
        end_chain = filename.index('_processed', start_chain)
        chain_identifier = filename[start_chain:end_chain]
        
        return het_identifier, chain_identifier
    except ValueError:
        return None, None

def get_resolution_from_pdb(pdb_file_path):
    try:
        with open(pdb_file_path, 'r') as f:
            for line in f:
                if line.startswith('REMARK   2 RESOLUTION.'):
                    parts = line.strip().split()
                    for i, part in enumerate(parts):
                        if 'ANGSTROM' in part.upper():
                            try:
                                resolution = float(parts[i - 1])
                                return resolution
                            except ValueError:
                                #logger.warning(f"Невозможно преобразовать разрешение в float для {pdb_file_path}")
                                return None
                    resolution_str = line.strip().split('RESOLUTION.')[-1].split()[0]
                    try:
                        resolution = float(resolution_str)
                        return resolution
                    except ValueError:
                        #logger.warning(f"Невозможно преобразовать разрешение в float для {pdb_file_path}")
                        return None
        return None
    except Exception as e:
        logger.error(f"Ошибка при чтении разрешения из {pdb_file_path}: {e}")
        return None

def remove_duplicate_groups(groups):
    unique_groups = []
    groups_sorted = sorted([sorted(group) for group in groups], key=lambda x: (-len(x), x))

    for group in groups_sorted:
        group_set = set(group)
        is_subset = False
        for unique_group in unique_groups:
            if group_set <= unique_group:
                is_subset = True
                break
        if not is_subset:
            unique_groups.append(group_set)
    return unique_groups

def process_groups_with_resolution(identical_groups, pdb_directory):
    processed_groups = []
    for group in identical_groups:
        processed_group = {file_name.split("_processed")[0] + "_processed" for file_name in group}
        processed_groups.append(processed_group)
    
    unique_groups = remove_duplicate_groups(processed_groups)
    final_groups = []

    for group in unique_groups:
        het_chain_groups = defaultdict(list)
        for file_name in group:
            het_identifier, chain_identifier = extract_het_and_chain_identifiers(file_name)
            key = (het_identifier, chain_identifier)
            het_chain_groups[key].append(file_name)

        selected_structures = []
        for key, structures in het_chain_groups.items():
            best_structure = None
            best_resolution = None
            for structure in structures:
                pdb_file_path = os.path.join(pdb_directory, f"{structure}.pdb")
                if not os.path.exists(pdb_file_path):
                    logger.warning(f"Файл {pdb_file_path} не найден.")
                    continue
                resolution = get_resolution_from_pdb(pdb_file_path)
                if resolution is None:
                    logger.warning(f"Разрешение не найдено для {structure}")
                    continue
                if best_resolution is None or resolution < best_resolution:
                    best_resolution = resolution
                    best_structure = structure
            if best_structure:
                selected_structures.append(best_structure)
            else:
                selected_structures.append(structures[0])
        final_groups.append(set(selected_structures))
    return final_groups

def remove_similar_structures(pickle_path, pdb_directory):
    identical_groups = json.load(open(pickle_path))
    
    initial_count = sum(len(group) for group in identical_groups)
    final_groups = process_groups_with_resolution(identical_groups, pdb_directory)
    
    total_files = set()
    for group in final_groups:
        total_files.update({file + ".pdb" for file in group})
    
    final_count = len(total_files)
    deleted_files = 0

    for filename in os.listdir(pdb_directory):
        file_path = os.path.join(pdb_directory, filename)
        # Удаляем файл, если его имя с расширением .pdb отсутствует в total_files
        if filename.endswith(".pdb") and filename not in total_files:
            os.remove(file_path)
            deleted_files += 1

    deleted_percentage = (deleted_files / (deleted_files + final_count)) * 100
    logger.info(f"На входе было {initial_count} структур.")
    logger.info(f"Осталось {final_count} уникальных структур.")
    logger.info(f"Удалено {deleted_files} файлов, что составляет {deleted_percentage:.2f}% от общего числа.")

identical_groups_path = "../data/identical_groups.json"
pdb_directory = "../lpce/tests/separated"
remove_similar_structures(identical_groups_path, pdb_directory)
# Out:
# Разрешение не найдено для 1a2s_bioml_1_HEC_chains_A_processed
# Разрешение не найдено для 1akk_bioml_1_HEC_chains_A_processed
# Разрешение не найдено для 1aw3_bioml_1_HEM_chains_A_processed
# На входе было 210 структур.
# Осталось 183 уникальных структур.
# Удалено 0 файлов, что составляет 0.00% от общего числа.

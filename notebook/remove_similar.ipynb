# %%
import subprocess
import sys
from pathlib import Path
from loguru import logger
from tqdm import tqdm
import tempfile

logger.remove()
logger.add(sys.stdout, format="{message}", level="INFO")

def run_foldseek(input_dir, tmscore_threshold=0.5, fident_threshold=0.9, n_jobs=224):
    """
    Runs Foldseek with specified parameters.

    :param input_dir: Directory containing input PDB files.
    :param tmscore_threshold: TM-score threshold for Foldseek.
    :param fident_threshold: Identity threshold for grouping results.
    :param n_jobs: Number of threads for Foldseek.
    """
    identical_pairs = {}

    with tempfile.TemporaryDirectory() as tmp_dir:
        output_dir = Path(tmp_dir)
        db_path = output_dir / "foldseek_db"
        aln_output = output_dir / "alignment_results.m8"
        foldseek_log = "foldseek_output.log"
        foldseek_bin = "/home/nikolenko/work/soft/foldseek/bin/foldseek"
        prostt5_path = "/home/nikolenko/work/soft/prostt5_model"

        logger.info("Starting run_foldseek")
        logger.info(f"Input directory: {input_dir}")
        logger.info(f"Foldseek binary: {foldseek_bin}")

        try:
            # Handle the 'createdb' step
            with open(foldseek_log, "w") as log_file:
                logger.info("Creating Foldseek database...")
                createdb_command = [
                    foldseek_bin,
                    "createdb",
                    str(input_dir),
                    str(db_path),
                    "--threads", str(n_jobs)
                ]
                process = subprocess.Popen(
                    createdb_command,
                    stdout=subprocess.PIPE,
                    stderr=subprocess.STDOUT,
                    universal_newlines=True
                )
                logger.info("createdb process started")

                # Initialize progress bar for 'createdb'
                total_equals_createdb = 65  # Assuming progress bar has 65 '=' characters
                pbar_createdb = tqdm(total=total_equals_createdb, desc="Creating Database", unit="chars")

                for line in process.stdout:
                    log_file.write(line)
                    if line.startswith('[') and ']' in line:
                        # Extract the progress bar part
                        progress_bar = line[line.find('['):line.find(']')+1]
                        num_equals = progress_bar.count('=')
                        pbar_createdb.n = num_equals
                        pbar_createdb.refresh()
                process.wait()
                pbar_createdb.close()
                if process.returncode != 0:
                    logger.error("Foldseek exited with an error during 'createdb'")
                    raise RuntimeError("Foldseek 'createdb' exited with an error.")
                logger.info(f"Database created at {db_path}")

            # Handle the 'easy-search' step
            with open(foldseek_log, "a") as log_file:
                logger.info("Starting easy-search...")
                command = [
                    foldseek_bin,
                    "easy-search",
                    str(db_path),
                    str(db_path),
                    str(aln_output),
                    str(output_dir),
                    "--format-output", "query,target,fident,evalue",
                    "--max-seqs", "10000",
                    "--alignment-type", "2",
                    "--tmscore-threshold", str(tmscore_threshold),
                    "--threads", str(n_jobs),
                    "--prostt5-model", prostt5_path 
                ]

                process = subprocess.Popen(
                    command,
                    stdout=subprocess.PIPE,
                    stderr=subprocess.STDOUT,
                    universal_newlines=True
                )

                logger.info("easy-search process started")

                # Initialize progress bar for 'easy-search'
                total_equals_easysearch = 5 * 65
                pbar_easysearch = tqdm(total=total_equals_easysearch, desc="Foldseek Progress", unit="chars")

                # Read the output character by character
                while True:
                    char = process.stdout.read(1)
                    if not char:
                        break
                    log_file.write(char)
                    if char == '=':
                        pbar_easysearch.update(1)

                process.wait()
                pbar_easysearch.close()

                if process.returncode != 0:
                    logger.error("Foldseek exited with an error in easy-search")
                    raise RuntimeError("Foldseek exited with an error.")

        except subprocess.CalledProcessError as e:
            logger.error(f"Foldseek failed to create the database: {e}")
            sys.exit(1)

        # Reading and processing Foldseek results
        logger.info("Reading Foldseek alignment results")
        with open(aln_output, 'r') as f:
            for line in f:
                query, target, fident, evalue = line.strip().split()[:4]
                fident = float(fident)
                if fident >= fident_threshold:
                    if query not in identical_pairs:
                        identical_pairs[query] = {query}
                    identical_pairs[query].add(target)

        logger.info("Grouping identical structures")
        groups = []
        visited = set()
        for key, group in identical_pairs.items():
            if key not in visited:
                groups.append(group)
                visited.update(group)

        logger.info(f"run_foldseek completed, found {len(groups)} groups of identical structures")
        return groups


def find_identical_in_directory_foldseek(input_dir, tmscore_threshold=0.5, fident_threshold=0.9, n_jobs=224):
    """
    High-level function to find identical structures using Foldseek.

    :param input_dir: Directory with input PDB files.
    :param tmscore_threshold: TM-score threshold for Foldseek.
    :param fident_threshold: Identity threshold for grouping results.
    :param n_jobs: Number of threads for Foldseek.
    :return: List of groups of identical structures.
    """
    input_dir = Path(input_dir)

    logger.info(f"Searching for identical structures in {input_dir} with Foldseek")
    logger.info(f"tmscore_threshold = {tmscore_threshold}, fident_threshold = {fident_threshold}, n_jobs = {n_jobs}")

    groups = run_foldseek(input_dir, tmscore_threshold, fident_threshold, n_jobs)

    logger.info(f"Search completed. Found {len(groups)} groups of identical structures.")
    return groups

# %%
identical_groups = find_identical_in_directory_foldseek("../lpce/tests/separated", tmscore_threshold=0.8, fident_threshold=0.8, n_jobs=112)
#identical_groups = find_identical_in_directory_foldseek("/mnt/ligandpro/db/LPCE/separated", tmscore_threshold=0.8, fident_threshold=0.8, n_jobs=64)
# Out:
# Searching for identical structures in ../lpce/tests/separated with Foldseek
# tmscore_threshold = 0.8, fident_threshold = 0.8, n_jobs = 112
# Starting run_foldseek
# Input directory: ../lpce/tests/separated
# Foldseek binary: /home/nikolenko/work/soft/foldseek/bin/foldseek
# Creating Foldseek database...
# createdb process started
# Creating Database: 100%|██████████| 65/65 [00:00<00:00, 353.10chars/s]
# Database created at /tmp/tmpdvi1dr6e/foldseek_db
# Starting easy-search...
# easy-search process started
# Foldseek Progress: 100%|██████████| 325/325 [00:01<00:00, 199.54chars/s]
# Reading Foldseek alignment results
# Grouping identical structures
# run_foldseek completed, found 121 groups of identical structures
# Search completed. Found 121 groups of identical structures.

# %%
identical_groups
# Out:
# [{'4a22_bioml_1_TD4_chains_A_B_processed_A',
#   '4a22_bioml_1_TD4_chains_A_B_processed_B'},
#  {'5a2d_bioml_1_CHT_chains_A_processed',
#   '5a2d_bioml_2_ETX_chains_D_processed'},
#  {'4a1o_bioml_1_AMZ_chains_A_B_processed',
#   '4a1o_bioml_1_AMZ_chains_A_B_processed_A',
#   '4a1o_bioml_1_AMZ_chains_A_B_processed_B'},
#  {'5a4k_bioml_1_FAD_chains_B_C_processed',
#   '5a4k_bioml_1_FAD_chains_B_C_processed_B',
#   '5a4k_bioml_1_FAD_chains_B_C_processed_C'},
#  {'5a14_bioml_1_LQ5_chains_A_processed'},
#  {'8a2v_bioml_1_FMN_chains_A_processed',
#   '8a4e_bioml_1_FMA_chains_A_processed',
#   '8a4e_bioml_1_FMN_chains_A_processed'},
#  {'8a4g_bioml_1_CD_chains_A_processed'},
#  {'1a47_bioml_1_ADH_chains_A_processed'},
#  {'1a4g_bioml_1_ZMR_chains_A_processed'},
#  {'4a2u_bioml_1_CMP_chains_A_B_processed_A',
#   '4a2u_bioml_1_CMP_chains_A_B_processed_B'},
#  {'7a1u_bioml_1_FUA_chains_A_processed'},
#  {'7a1j_bioml_1_ZN_chains_A_processed',
#   '7a1o_bioml_1_ZN_chains_A_B_processed',
#   '7a1o_bioml_1_ZN_chains_A_B_processed_A',
#   '7a1o_bioml_1_ZN_chains_A_B_processed_B',
#   '7a1q_bioml_1_ZN_chains_A_B_processed',
#   '7a1q_bioml_1_ZN_chains_A_B_processed_A',
#   '7a1q_bioml_1_ZN_chains_A_B_processed_B'},
#  {'8a2h_bioml_1_OK6_chains_A_B_processed',
#   '8a2h_bioml_1_OK6_chains_A_B_processed_A',
#   '8a2h_bioml_1_OK6_chains_A_B_processed_B',
#   '8a2i_bioml_1_KWF_chains_A_B_processed',
#   '8a2i_bioml_1_KWF_chains_A_B_processed_A',
#   '8a2i_bioml_1_KWF_chains_A_B_processed_B',
#   '8a2j_bioml_1_KWO_chains_A_B_processed',
#   '8a2j_bioml_1_KWO_chains_A_B_processed_A',
#   '8a2j_bioml_1_KWO_chains_A_B_processed_B',
#   '8a2k_bioml_1_KXD_chains_A_B_processed',
#   '8a2k_bioml_1_KXD_chains_A_B_processed_A',
#   '8a2k_bioml_1_KXD_chains_A_B_processed_B'},
#  {'2a4o_bioml_1_ACE_chains_A_processed'},
#  {'4a2l_bioml_1_PGE_chains_A_processed',
#   '4a2l_bioml_1_PGE_chains_B_processed',
#   '4a2l_bioml_3_PGE_chains_F_processed',
#   '4a2m_bioml_1_NGS_chains_A_B_processed_A',
#   '4a2m_bioml_1_NGS_chains_A_B_processed_B',
#   '4a2m_bioml_2_NGS_chains_C_D_processed_C',
#   '4a2m_bioml_2_NGS_chains_C_D_processed_D'},
#  {'5a1g_bioml_1_PPK_chains_A_processed',
#   '5a1i_bioml_1_MET_chains_A_processed',
#   '5a1i_bioml_1_SAM_chains_A_processed'},
#  {'5a24_bioml_1_E64_chains_A_processed'},
#  {'6a1d_bioml_1_6R2_chains_A_processed',
#   '6a1e_bioml_1_FPS_chains_A_processed',
#   '6a2d_bioml_1_6R2_chains_B_processed'},
#  {'6a20_bioml_1_ADP_chains_A_processed'},
#  {'8a1h_bioml_1_FAD_chains_A_processed'},
#  {'4a4l_bioml_1_939_chains_A_processed',
#   '4a4o_bioml_1_664_chains_A_processed'},
#  {'5a12_bioml_1_HEM_chains_A_processed',
#   '5a13_bioml_1_HEM_chains_F_processed'},
#  {'6a4j_bioml_1_FAD_chains_A_B_processed_A',
#   '6a4j_bioml_1_FAD_chains_A_B_processed_B'},
#  {'2a2z_bioml_1_MG_chains_A_processed', '2a2z_bioml_1_MG_chains_B_processed'},
#  {'2a40_bioml_1_ATP_chains_A_processed',
#   '8a2y_bioml_1_ADP_chains_C_processed'},
#  {'6a4i_bioml_1_HEM_chains_A_B_processed_A',
#   '6a4i_bioml_1_HEM_chains_A_B_processed_B',
#   '6a4i_bioml_1_HEM_chains_C_D_processed',
#   '6a4i_bioml_1_HEM_chains_C_D_processed_C',
#   '6a4i_bioml_1_HEM_chains_C_D_processed_D'},
#  {'3a2o_bioml_1_KNJ_chains_A_B_processed',
#   '3a2o_bioml_1_KNJ_chains_A_B_processed_A',
#   '3a2o_bioml_1_KNJ_chains_A_B_processed_B'},
#  {'5a2m_bioml_1_WX5_chains_H_processed'},
#  {'7a2p_bioml_1_PGE_chains_A_processed'},
#  {'5a4e_bioml_1_7QQ_chains_A_processed',
#   '6a1f_bioml_1_PGE_chains_A_processed',
#   '7a4r_bioml_1_QY8_chains_A_processed',
#   '7a4r_bioml_2_QY8_chains_B_processed',
#   '7a4w_bioml_1_QYH_chains_A_processed'},
#  {'8a1v_bioml_1_UQ2_chains_B_processed',
#   '8a1w_bioml_1_FMN_chains_B_processed'},
#  {'7a4k_bioml_1_QZT_chains_A_processed'},
#  {'7a1x_bioml_1_GDP_chains_A_processed'},
#  {'8a12_bioml_1_ADP_chains_A_processed'},
#  {'3a4m_bioml_1_ADP_chains_A_processed'},
#  {'2a1t_bioml_1_AMP_chains_S_processed',
#   '2a1u_bioml_1_FAD_chains_A_B_processed',
#   '2a1u_bioml_1_FAD_chains_A_B_processed_B'},
#  {'8a1r_bioml_1_FAD_chains_A_B_processed_A',
#   '8a1r_bioml_1_FAD_chains_A_B_processed_B'},
#  {'1xa_bioml_1_ARG_chains_A_B_F_processed_A',
#   '1xa_bioml_1_ARG_chains_A_B_F_processed_B',
#   '1xa_bioml_1_ARG_chains_A_B_F_processed_F',
#   '1xa_bioml_1_ARG_chains_A_C_D_processed_A',
#   '1xa_bioml_1_ARG_chains_A_C_D_processed_C',
#   '1xa_bioml_1_ARG_chains_A_C_D_processed_D',
#   '1xa_bioml_1_ARG_chains_A_D_F_processed_A',
#   '1xa_bioml_1_ARG_chains_A_D_F_processed_D',
#   '1xa_bioml_1_ARG_chains_A_D_F_processed_F'},
#  {'1a27_bioml_1_NAP_chains_A_processed'},
#  {'1a49_bioml_1_ATP_chains_A_processed'},
#  {'1a25_bioml_1_PSE_chains_B_processed'},
#  {'2a27_bioml_1_DTT_chains_A_E_processed_A',
#   '2a27_bioml_1_DTT_chains_A_E_processed_E',
#   '2a2a_bioml_1_DTT_chains_A_B_processed',
#   '2a2a_bioml_1_DTT_chains_A_B_processed_A',
#   '2a2a_bioml_1_DTT_chains_A_B_processed_B'},
#  {'2a1t_bioml_1_FAD_chains_A_B_C_processed_A',
#   '2a1t_bioml_1_FAD_chains_A_B_C_processed_B',
#   '2a1t_bioml_1_FAD_chains_A_B_C_processed_C',
#   '2a1t_bioml_1_FAD_chains_A_B_D_processed_A',
#   '2a1t_bioml_1_FAD_chains_A_B_D_processed_B',
#   '2a1t_bioml_1_FAD_chains_A_B_D_processed_D',
#   '2a1t_bioml_1_FAD_chains_A_C_D_processed_A',
#   '2a1t_bioml_1_FAD_chains_A_C_D_processed_C',
#   '2a1t_bioml_1_FAD_chains_A_C_D_processed_D',
#   '2a1t_bioml_1_FAD_chains_B_C_D_processed_B',
#   '2a1t_bioml_1_FAD_chains_B_C_D_processed_C',
#   '2a1t_bioml_1_FAD_chains_B_C_D_processed_D',
#   '2a1t_bioml_1_FAD_chains_C_D_R_processed_C',
#   '2a1t_bioml_1_FAD_chains_C_D_R_processed_D'},
#  {'4a1z_bioml_1_MG_chains_A_processed',
#   '4a28_bioml_1_ADP_chains_A_B_processed_A',
#   '4a28_bioml_1_ADP_chains_A_B_processed_B'},
#  {'148l_bioml_1_MUB_chains_E_S_processed',
#   '148l_bioml_1_MUB_chains_E_S_processed_E',
#   '2a4t_bioml_1_HED_chains_A_processed'},
#  {'6a1a_bioml_1_FMN_chains_A_processed', '6a1w_bioml_1_MG_chains_A_processed'},
#  {'3a1s_bioml_1_GDP_chains_A_processed',
#   '3a1s_bioml_2_GDP_chains_B_processed',
#   '3a1u_bioml_1_MRD_chains_A_processed'},
#  {'1a4f_bioml_1_HEM_chains_B_processed'},
#  {'5a4d_bioml_1_NAP_chains_A_processed',
#   '5a4d_bioml_5_NAP_chains_E_processed'},
#  {'3a2h_bioml_1_TEJ_chains_A_processed',
#   '3a40_bioml_1_23R_chains_X_processed'},
#  {'3a15_bioml_1_HEM_chains_A_processed',
#   '3a16_bioml_1_HEM_chains_A_B_processed',
#   '3a16_bioml_1_HEM_chains_A_B_processed_A',
#   '3a16_bioml_1_HEM_chains_A_B_processed_B'},
#  {'3a2y_bioml_1_TS5_chains_A_processed'},
#  {'5a1j_bioml_1_FE_chains_A_processed'},
#  {'19hc_bioml_1_HEM_chains_A_processed'},
#  {'2a2c_bioml_1_NG1_chains_A_processed'},
#  {'3a25_bioml_1_SAM_chains_A_processed'},
#  {'8a11_bioml_1_PLP_chains_A_B_processed_A',
#   '8a11_bioml_1_PLP_chains_A_B_processed_B',
#   '8a11_bioml_1_PLP_chains_C_D_processed_C',
#   '8a11_bioml_1_PLP_chains_C_D_processed_D'},
#  {'8a26_bioml_1_MLA_chains_A_processed'},
#  {'5a1p_bioml_1_HEM_chains_A_processed',
#   '5a1r_bioml_1_STR_chains_A_processed'},
#  {'7a2h_bioml_1_QX2_chains_A_processed'},
#  {'7a2a_bioml_1_7G9_chains_A_processed',
#   '7a2a_bioml_2_7G9_chains_B_processed'},
#  {'7a2i_bioml_1_HEM_chains_B_processed'},
#  {'3a2v_bioml_1_PER_chains_A_processed',
#   '3a2w_bioml_1_PER_chains_B_processed'},
#  {'2a1h_bioml_1_PLP_chains_A_processed'},
#  {'3a27_bioml_1_SAM_chains_A_processed'},
#  {'1a4e_bioml_1_AZI_chains_A_processed'},
#  {'7a4v_bioml_1_ADP_chains_A_processed'},
#  {'5a2z_bioml_1_GTP_chains_A_processed',
#   '5a2z_bioml_1_GTP_chains_B_processed'},
#  {'1a2g_bioml_1_HEM_chains_A_processed'},
#  {'7a2g_bioml_1_FE_chains_A_processed'},
#  {'2a18_bioml_1_NH4_chains_A_processed'},
#  {'4a14_bioml_1_ADP_chains_A_processed'},
#  {'.4x6h_bioml_1_3XT_chains_A_processed',
#   '.4x6h_bioml_1_I37_chains_A_processed'},
#  {'1a4f_bioml_1_HEM_chains_A_processed'},
#  {'6a2w_bioml_1_A86_chains_A_processed'},
#  {'3a4z_bioml_1_HEM_chains_A_processed'},
#  {'8a2o_bioml_1_TEP_chains_A_processed'},
#  {'7a1f_bioml_1_FE_chains_A_processed'},
#  {'2a2q_bioml_1_PBZ_chains_H_processed'},
#  {'1a2q_bioml_1_ACN_chains_A_processed'},
#  {'2a14_bioml_1_SAH_chains_A_processed'},
#  {'8a4u_bioml_2_PGE_chains_B_processed'},
#  {'3a1d_bioml_1_ADP_chains_A_processed'},
#  {'6a2j_bioml_1_HEM_chains_A_processed'},
#  {'3a20_bioml_1_FMN_chains_A_B_processed_A',
#   '3a20_bioml_1_FMN_chains_A_B_processed_B'},
#  {'3a1l_bioml_1_HEM_chains_A_processed'},
#  {'8a4n_bioml_1_NAP_chains_A_processed'},
#  {'8a21_bioml_1_PIM_chains_A_processed'},
#  {'3a28_bioml_1_NAD_chains_C_processed'},
#  {'5a1t_bioml_1_OXM_chains_A_processed'},
#  {'8a4b_bioml_1_GTP_chains_B_processed'},
#  {'6a4q_bioml_1_GAI_chains_A_processed'},
#  {'2a26_bioml_1_CXS_chains_B_processed'},
#  {'1a28_bioml_1_STR_chains_A_processed'},
#  {'4a45_bioml_1_NGA_chains_A_processed_A'},
#  {'5a44_bioml_1_RET_chains_A_processed'},
#  {'3a2b_bioml_1_SER_chains_A_processed'},
#  {'2a1u_bioml_1_FAD_chains_A_B_processed',
#   '2a1u_bioml_1_FAD_chains_A_B_processed_A'},
#  {'3a4v_bioml_1_NAD_chains_A_processed'},
#  {'7a28_bioml_1_GAI_chains_A_processed'},
#  {'2a1o_bioml_1_HEM_chains_A_processed'},
#  {'4a4m_bioml_1_RET_chains_A_processed'},
#  {'17gs_bioml_1_GTX_chains_A_B_processed_A',
#   '17gs_bioml_1_GTX_chains_A_B_processed_B'},
#  {'4a2n_bioml_1_SAH_chains_B_processed'},
#  {'6a4d_bioml_1_9RC_chains_A_B_processed_A',
#   '6a4d_bioml_1_9RC_chains_A_B_processed_B',
#   '6a4d_bioml_1_9RC_chains_B_processed'},
#  {'4a2a_bioml_1_ATP_chains_A_processed'},
#  {'6a2m_bioml_1_NAP_chains_A_processed'},
#  {'104m_bioml_1_HEM_chains_A_processed'},
#  {'12as_bioml_1_ASN_chains_A_processed'},
#  {'7a11_bioml_1_XL3_chains_A_processed'},
#  {'2a2g_bioml_1_LEO_chains_A_processed'},
#  {'7a20_bioml_1_144_chains_B_processed'},
#  {'8a1w_bioml_1_FAD_chains_F_processed'},
#  {'7a23_bioml_1_FMN_chains_A_processed'},
#  {'6a15_bioml_1_HEM_chains_A_processed'},
#  {'1a2s_bioml_1_HEC_chains_A_processed'},
#  {'2a1t_bioml_1_FAD_chains_C_D_R_processed_R'},
#  {'3a4p_bioml_1_IPA_chains_A_processed'},
#  {'6a2u_bioml_1_FAD_chains_B_processed'},
#  {'1a4r_bioml_1_MG_chains_A_processed'},
#  {'3a1i_bioml_1_UNU_chains_A_processed'}]

# %%
import json
identical_groups_json_compatible = [list(group) for group in identical_groups]
with open("../data/identical_groups.json", "w") as f:
    json.dump(identical_groups_json_compatible, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import json
# ----> 2 identical_groups_json_compatible = [list(group) for group in identical_groups]
#       3 with open("../data/identical_groups.json", "w") as f:
#       4     json.dump(identical_groups_json_compatible, f)
#
# NameError: name 'identical_groups' is not defined

# %%
import os
import json
from collections import defaultdict
from loguru import logger

def extract_het_and_chain_identifiers(filename: str) -> tuple[str, str] | tuple[None, None]:
    try:
        chain_tag = "_chains_"
        processed_tag = "_processed"
        
        start_bioml = filename.index("bioml_") + len("bioml_")

        pos_underscore = filename.index('_', start_bioml)

        start_ligand = pos_underscore + 1
        
        chain_start = filename.index(chain_tag, start_ligand)
        ligand_part = filename[start_ligand:chain_start]
        #logger.info(f"ligand_part: {ligand_part}")

        chain_identifier_start = chain_start + len(chain_tag)
        processed_pos = filename.index(processed_tag, chain_identifier_start)
        chain_identifier = filename[chain_identifier_start:processed_pos]
        
        return (ligand_part, chain_identifier)
    except ValueError:
        return None, None


def get_resolution_from_pdb(pdb_file_path):
    try:
        with open(pdb_file_path, 'r') as f:
            for line in f:
                if line.startswith('REMARK   2 RESOLUTION.'):
                    parts = line.strip().split()
                    for i, part in enumerate(parts):
                        if 'ANGSTROM' in part.upper():
                            try:
                                resolution = float(parts[i - 1])
                                return resolution
                            except ValueError:
                                #logger.warning(f"Невозможно преобразовать разрешение в float для {pdb_file_path}")
                                return None
                    resolution_str = line.strip().split('RESOLUTION.')[-1].split()[0]
                    try:
                        resolution = float(resolution_str)
                        return resolution
                    except ValueError:
                        #logger.warning(f"Невозможно преобразовать разрешение в float для {pdb_file_path}")
                        return None
        return None
    except Exception as e:
        logger.error(f"Ошибка при чтении разрешения из {pdb_file_path}: {e}")
        return None

def remove_duplicate_groups(groups):
    unique_groups = []
    groups_sorted = sorted([sorted(group) for group in groups], key=lambda x: (-len(x), x))

    for group in groups_sorted:
        group_set = set(group)
        is_subset = False
        for unique_group in unique_groups:
            if group_set <= unique_group:
                is_subset = True
                break
        if not is_subset:
            unique_groups.append(group_set)
    return unique_groups

def process_groups_with_resolution(identical_groups, pdb_directory):
    processed_groups = []
    for group in identical_groups:
        processed_group = {file_name.split("_processed")[0] + "_processed" for file_name in group}
        processed_groups.append(processed_group)
    
    unique_groups = remove_duplicate_groups(processed_groups)
    final_groups = []

    for group in unique_groups:
        het_chain_groups = defaultdict(list)
        for file_name in group:
            het_identifier, chain_identifier = extract_het_and_chain_identifiers(file_name)
            key = (het_identifier, chain_identifier)
            het_chain_groups[key].append(file_name)

        selected_structures = []
        for key, structures in het_chain_groups.items():
            best_structure = None
            best_resolution = None
            for structure in structures:
                pdb_file_path = os.path.join(pdb_directory, f"{structure}.pdb")
                if not os.path.exists(pdb_file_path):
                    logger.warning(f"Файл {pdb_file_path} не найден.")
                    continue
                resolution = get_resolution_from_pdb(pdb_file_path)
                if resolution is None:
                    logger.warning(f"Разрешение не найдено для {structure}")
                    continue
                if best_resolution is None or resolution < best_resolution:
                    best_resolution = resolution
                    best_structure = structure
            if best_structure:
                selected_structures.append(best_structure)
            else:
                selected_structures.append(structures[0])
        final_groups.append(set(selected_structures))
    return final_groups

def remove_similar_structures(pickle_path, pdb_directory):
    identical_groups = json.load(open(pickle_path))
    
    initial_count = sum(len(group) for group in identical_groups)
    final_groups = process_groups_with_resolution(identical_groups, pdb_directory)
    
    total_files = set()
    for group in final_groups:
        total_files.update({file + ".pdb" for file in group})
    
    final_count = len(total_files)
    deleted_files = 0

    for filename in os.listdir(pdb_directory):
        file_path = os.path.join(pdb_directory, filename)
        # Удаляем файл, если его имя с расширением .pdb отсутствует в total_files
        if filename.endswith(".pdb") and filename not in total_files:
            os.remove(file_path)
            deleted_files += 1

    deleted_percentage = (deleted_files / (deleted_files + final_count)) * 100
    logger.info(f"На входе было {initial_count} структур.")
    logger.info(f"Осталось {final_count} уникальных структур.")
    logger.info(f"Удалено {deleted_files} файлов, что составляет {deleted_percentage:.2f}% от общего числа.")

identical_groups_path = "../data/identical_groups.json"
pdb_directory = "../lpce/tests/separated"
remove_similar_structures(identical_groups_path, pdb_directory)
# Out:
# Файл ../lpce/tests/separated/212l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/249l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/246l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/187l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/183l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/242l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/257l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/184l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/244l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/186l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/248l_bioml_1_HED_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/148l_bioml_1_MUB_chains_E_S_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a41_bioml_1_ATP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a42_bioml_1_ATP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2t_bioml_1_ADP_chains_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2z_bioml_1_ADP_chains_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2r_bioml_1_ADP_chains_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2u_bioml_1_ADP_chains_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2s_bioml_1_ADP_chains_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2y_bioml_1_ADP_chains_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a4r_bioml_1_QY8_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a4r_bioml_2_QY8_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a4e_bioml_2_7QQ_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a4w_bioml_1_QYH_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a4e_bioml_4_7QQ_chains_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a4e_bioml_1_7QQ_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a4w_bioml_2_QYH_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a4e_bioml_3_7QQ_chains_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a1n_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a19_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a24_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a13_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a11_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a1b_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a1w_bioml_1_MG_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a1s_bioml_2_GDP_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a1u_bioml_1_MRD_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a1v_bioml_2_MRD_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a1u_bioml_2_MRD_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a1t_bioml_1_GDP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/4a2m_bioml_1_NGS_chains_A_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/4a2m_bioml_2_NGS_chains_C_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/4a2l_bioml_3_PGE_chains_E_processed.pdb не найден.
# Файл ../lpce/tests/separated/4a2l_bioml_3_PGE_chains_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/4a2l_bioml_1_PGE_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a2n_bioml_1_NAP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a2o_bioml_1_NAP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a2p_bioml_1_NAP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a2l_bioml_1_NAP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a2k_bioml_1_NAP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1x_bioml_1_FAD_chains_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1u_bioml_1_FAD_chains_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1t_bioml_1_FAD_chains_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1v_bioml_1_FAD_chains_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1y_bioml_1_FAD_chains_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1v_bioml_1_UQ2_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1y_bioml_1_FMN_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1t_bioml_1_FMN_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1u_bioml_1_FMN_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a1x_bioml_1_FMN_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a2g_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/101m_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/105m_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/112m_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a1t_bioml_1_FAD_chains_A_B_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a1t_bioml_1_FAD_chains_B_C_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a1t_bioml_1_FAD_chains_C_D_R_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a1t_bioml_1_FAD_chains_A_B_C_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a1j_bioml_1_ZN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a1k_bioml_1_ZN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a1m_bioml_1_ZN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a1o_bioml_1_ZN_chains_A_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a18_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a15_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a17_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a2h_bioml_1_TEJ_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a2i_bioml_1_TEJ_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a2j_bioml_1_TEJ_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a18_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a16_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a17_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a2d_bioml_1_6R2_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a1e_bioml_1_FPS_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a2d_bioml_1_6R2_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a4p_bioml_1_GAI_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a4n_bioml_1_GAI_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a4o_bioml_1_GAI_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a1y_bioml_1_GDP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a1w_bioml_1_GDP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a47_bioml_1_GDP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2i_bioml_1_KWF_chains_A_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2j_bioml_1_KWO_chains_A_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2h_bioml_1_OK6_chains_A_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/1xa_bioml_1_ARG_chains_A_B_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/1xa_bioml_1_ARG_chains_A_C_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a1n_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a1m_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a19_bioml_1_PPK_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a1i_bioml_1_MET_SAM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a2w_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a4e_bioml_1_FMA_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/1a2f_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a1t_bioml_1_AMP_chains_S_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a27_bioml_1_DTT_chains_A_E_processed.pdb не найден.
# Файл ../lpce/tests/separated/2a2z_bioml_1_MG_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a1n_bioml_1_NAD_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a2w_bioml_1_PER_chains_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/3a4h_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/4a1z_bioml_1_MG_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/4a4o_bioml_1_664_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a13_bioml_1_HEM_chains_F_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a1p_bioml_1_HEM_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a2d_bioml_2_ETX_chains_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a2z_bioml_1_GTP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/5a4d_bioml_1_NAP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a1z_bioml_1_ADP_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a4d_bioml_1_9RC_chains_A_B_processed.pdb не найден.
# Файл ../lpce/tests/separated/6a4i_bioml_1_HEM_chains_C_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a24_bioml_1_FMN_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a2f_bioml_1_GAI_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a2a_bioml_1_7G9_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/7a2o_bioml_1_PGE_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a11_bioml_1_PLP_chains_C_D_processed.pdb не найден.
# Файл ../lpce/tests/separated/8a25_bioml_1_MLA_chains_A_processed.pdb не найден.
# Файл ../lpce/tests/separated/.4x6h_bioml_1_3XT_I37_chains_A_processed.pdb не найден.
# Разрешение не найдено для 1a2s_bioml_1_HEC_chains_A_processed
# Файл ../lpce/tests/separated/7a23_bioml_1_CDL_chains_I_processed.pdb не найден.
# final_groups: [{'148l_bioml_1_MUB_chains_E_S_processed', '2a4t_bioml_1_HED_chains_A_processed'}, {'2a40_bioml_1_ATP_chains_A_processed', '8a2t_bioml_1_ADP_chains_C_processed'}, {'7a4r_bioml_2_QY8_chains_B_processed', '7a4r_bioml_1_QY8_chains_A_processed', '6a1f_bioml_1_PGE_chains_A_processed', '5a4e_bioml_2_7QQ_chains_B_processed', '7a4w_bioml_1_QYH_chains_A_processed', '5a4e_bioml_4_7QQ_chains_D_processed', '5a4e_bioml_1_7QQ_chains_A_processed', '7a4w_bioml_2_QYH_chains_B_processed', '5a4e_bioml_3_7QQ_chains_C_processed'}, {'6a1a_bioml_1_FMN_chains_A_processed', '6a1w_bioml_1_MG_chains_A_processed'}, {'3a1s_bioml_2_GDP_chains_B_processed', '3a1u_bioml_1_MRD_chains_A_processed', '3a1v_bioml_2_MRD_chains_B_processed', '3a1s_bioml_1_GDP_chains_A_processed'}, {'4a2m_bioml_1_NGS_chains_A_B_processed', '4a2m_bioml_2_NGS_chains_C_D_processed', '4a2l_bioml_3_PGE_chains_E_processed', '4a2l_bioml_1_PGE_chains_A_processed', '4a2l_bioml_3_PGE_chains_F_processed', '4a2l_bioml_1_PGE_chains_B_processed'}, {'6a2m_bioml_1_NAP_chains_A_processed'}, {'8a1w_bioml_1_FAD_chains_F_processed'}, {'8a1v_bioml_1_UQ2_chains_B_processed', '8a1w_bioml_1_FMN_chains_B_processed'}, {'104m_bioml_1_HEM_chains_A_processed'}, {'2a1t_bioml_1_FAD_chains_A_B_D_processed', '2a1t_bioml_1_FAD_chains_B_C_D_processed', '2a1t_bioml_1_FAD_chains_C_D_R_processed', '2a1t_bioml_1_FAD_chains_A_C_D_processed', '2a1t_bioml_1_FAD_chains_A_B_C_processed'}, {'7a1q_bioml_1_ZN_chains_A_B_processed', '7a1j_bioml_1_ZN_chains_A_processed'}, {'3a16_bioml_1_HEM_chains_A_B_processed', '3a18_bioml_1_HEM_chains_A_processed'}, {'3a2h_bioml_1_TEJ_chains_A_processed', '3a40_bioml_1_23R_chains_X_processed'}, {'6a15_bioml_1_HEM_chains_A_processed'}, {'6a1d_bioml_1_6R2_chains_A_processed', '6a1e_bioml_1_FPS_chains_A_processed', '6a2d_bioml_1_6R2_chains_B_processed'}, {'6a4q_bioml_1_GAI_chains_A_processed'}, {'7a1x_bioml_1_GDP_chains_A_processed'}, {'8a2i_bioml_1_KWF_chains_A_B_processed', '8a2j_bioml_1_KWO_chains_A_B_processed', '8a2h_bioml_1_OK6_chains_A_B_processed', '8a2k_bioml_1_KXD_chains_A_B_processed'}, {'1xa_bioml_1_ARG_chains_A_B_F_processed', '1xa_bioml_1_ARG_chains_A_D_F_processed', '1xa_bioml_1_ARG_chains_A_C_D_processed'}, {'2a1o_bioml_1_HEM_chains_A_processed'}, {'5a1i_bioml_1_MET_SAM_chains_A_processed', '5a1g_bioml_1_PPK_chains_A_processed'}, {'8a2v_bioml_1_FMN_chains_A_processed', '8a4e_bioml_1_FMA_FMN_chains_A_processed'}, {'1a2g_bioml_1_HEM_chains_A_processed'}, {'2a1t_bioml_1_AMP_chains_S_processed', '2a1u_bioml_1_FAD_chains_A_B_processed'}, {'2a27_bioml_1_DTT_chains_A_E_processed', '2a2a_bioml_1_DTT_chains_A_B_processed'}, {'2a2z_bioml_1_MG_chains_A_processed', '2a2z_bioml_1_MG_chains_B_processed'}, {'3a4v_bioml_1_NAD_chains_A_processed'}, {'3a2v_bioml_1_PER_chains_A_processed', '3a2w_bioml_1_PER_chains_B_processed'}, {'3a4z_bioml_1_HEM_chains_A_processed'}, {'4a1z_bioml_1_MG_chains_A_processed', '4a28_bioml_1_ADP_chains_A_B_processed'}, {'4a4l_bioml_1_939_chains_A_processed', '4a4o_bioml_1_664_chains_A_processed'}, {'5a13_bioml_1_HEM_chains_F_processed', '5a12_bioml_1_HEM_chains_A_processed'}, {'5a1p_bioml_1_HEM_chains_A_processed', '5a1r_bioml_1_STR_chains_A_processed'}, {'5a2d_bioml_1_CHT_chains_A_processed', '5a2d_bioml_2_ETX_chains_D_processed'}, {'5a2z_bioml_1_GTP_chains_A_processed', '5a2z_bioml_1_GTP_chains_B_processed'}, {'5a4d_bioml_5_NAP_chains_E_processed', '5a4d_bioml_1_NAP_chains_A_processed'}, {'6a20_bioml_1_ADP_chains_A_processed'}, {'6a4d_bioml_1_9RC_chains_B_processed', '6a4d_bioml_1_9RC_chains_A_B_processed'}, {'6a4i_bioml_1_HEM_chains_C_D_processed', '6a4i_bioml_1_HEM_chains_A_B_processed'}, {'7a23_bioml_1_FMN_chains_A_processed'}, {'7a28_bioml_1_GAI_chains_A_processed'}, {'7a2a_bioml_1_7G9_chains_A_processed', '7a2a_bioml_2_7G9_chains_B_processed'}, {'7a2p_bioml_1_PGE_chains_A_processed'}, {'8a11_bioml_1_PLP_chains_A_B_processed', '8a11_bioml_1_PLP_chains_C_D_processed'}, {'8a26_bioml_1_MLA_chains_A_processed'}, {'.4x6h_bioml_1_3XT_I37_chains_A_processed' ...
# На входе было 287 структур.
# Осталось 171 уникальных структур.
# Удалено 0 файлов, что составляет 0.00% от общего числа.
